-- %%
CREATE TABLE Pokemon (
    PokemonNo INT PRIMARY KEY,
    Name VARCHAR(50),
    Type1 VARCHAR(50),
    Type2 VARCHAR(50),
    Ability1 VARCHAR(50),
    Ability2 VARCHAR(50),
    Ability3 VARCHAR(50),
    HP INT,
    Attack INT,
    Defense INT,
    SpecialAttack INT,
    SpecialDefense INT,
    Speed INT
);
-- Out:
-- : Msg 2714, Level 16, State 6, Line 1
-- There is already an object named 'Pokemon' in the database.
-- Total execution time: 00:00:00.028

-- %%
INSERT INTO Pokemon 
(PokemonNo, Name, Type1, Type2, Ability1, Ability2, Ability3, HP, Attack, Defense, SpecialAttack, SpecialDefense, Speed) VALUES 
(001, 'Bulbasaur', 'Grass', 'Poison', 'Overgrow', 'Chlorophyll', NULL, 45, 49, 49, 65, 65, 45),
(002, 'Ivysaur', 'Grass', 'Poison', 'Overgrow', 'Chlorophyll', NULL, 60, 62, 63, 80, 80, 60),
(003, 'Venusaur', 'Grass', 'Poison', 'Overgrow', 'Chlorophyll', NULL, 80, 82, 83, 100, 100, 80),
(004, 'Charmander', 'Fire', NULL, 'Blaze', 'Solar Power', NULL, 39, 52, 43, 60, 50, 50),
(005, 'Charmeleon', 'Fire', NULL, 'Blaze', 'Solar Power', NULL, 58, 64, 58, 80, 65, 65),
(006, 'Charizard', 'Fire', 'Flying', 'Blaze', 'Solar Power', NULL, 78, 84, 78, 109, 85, 85),
(007, 'Squirtle', 'Water', NULL, 'Torrent', 'Rain Dish', NULL, 44, 48, 65, 50, 64, 64),
(008, 'Wartortle', 'Water', NULL, 'Torrent', 'Rain Dish', NULL, 59, 63, 80, 65, 80, 80),
(009, 'Blastoise', 'Water', NULL, 'Torrent', 'Rain Dish', NULL, 79, 83, 100, 85, 105, 105),
(010, 'Caterpie', 'Bug', NULL, 'Shield Dust', 'Run Away', NULL, 45, 30, 35, 20, 20, 45),
(011, 'Metapod', 'Bug', NULL, 'Shed Skin', NULL, NULL, 50, 20, 55, 25, 25, 30),
(012, 'Butterfree', 'Bug', 'Flying', 'Compoundeyes', 'Tinted Lens', NULL, 60, 45, 50, 90, 80, 80),
(013, 'Weedle', 'Bug', 'Poison', 'Shield Dust', 'Run Away', NULL, 40, 35, 30, 20, 20, 50),
(014, 'Kakuna', 'Bug', 'Poison', 'Shed Skin', NULL, NULL, 45, 25, 50, 25, 25, 35),
(015, 'Beedrill', 'Bug', 'Poison', 'Swarm', 'Sniper', NULL, 65, 90, 40, 45, 80, 75),
(016, 'Pidgey', 'Normal', 'Flying', 'Keen Eye', 'Tangled Feet', 'Big Pecks', 40, 45, 40, 35, 35, 56),
(017, 'Pidgeotto', 'Normal', 'Flying', 'Keen Eye', 'Tangled Feet', 'Big Pecks', 63, 60, 55, 50, 50, 71),
(018, 'Pidgeot', 'Normal', 'Flying', 'Keen Eye', 'Tangled Feet', 'Big Pecks', 83, 80, 75, 70, 70, 101),
(019, 'Rattata', 'Normal', NULL, 'Run Away', 'Guts', 'Hustle', 30, 56, 35, 25, 35, 72),
(020, 'Raticate', 'Normal', NULL, 'Run Away', 'Guts', 'Hustle', 55, 81, 60, 50, 70, 97),
(021, 'Spearow', 'Normal', 'Flying', 'Keen Eye', 'Sniper', NULL, 40, 60, 30, 31, 31, 70),
(022, 'Fearow', 'Normal', 'Flying', 'Keen Eye', 'Sniper', NULL, 65, 90, 65, 61, 61, 100),
(023, 'Ekans', 'Poison', NULL, 'Intimidate', 'Shed Skin', 'Unnerve', 35, 60, 44, 40, 54, 55),
(024, 'Arbok', 'Poison', NULL, 'Intimidate', 'Shed Skin', 'Unnerve', 60, 95, 69, 65, 79, 80),
(025, 'Pikachu', 'Electric', NULL, 'Static', 'Lighting Rod', NULL, 35, 55, 40, 50, 50, 90),
(026, 'Raichu', 'Electric', NULL, 'Static', 'Lighting Rod', NULL, 60, 90, 55, 90, 80, 110),
(027, 'Sandshrew', 'Ground', NULL, 'Sand Veil', 'Sand Rush', NULL, 50, 75, 85, 20, 30, 40),
(028, 'Sandslash', 'Ground', NULL, 'Sand Veil', 'Sand Rush', NULL, 75, 100, 110, 45, 55, 65),
(029, 'Nidoran♀', 'Poison', NULL, 'Poison Point', 'Rivalry', 'Hustle', 55, 47, 52, 40, 40, 41),
(030, 'Nidorina', 'Poison', NULL, 'Poison Point', 'Rivalry', 'Hustle', 70, 62, 67, 55, 55, 56),
(031, 'Nidoqueen', 'Poison', 'Ground', 'Poison Point', 'Rivalry', 'Sheer Force', 90, 92, 87, 75, 85, 76),
(032, 'Nidoran♂', 'Poison', NULL, 'Poison Point', 'Rivalry', 'Hustle', 46, 57, 40, 40, 40, 50),
(033, 'Nidorino', 'Poison', NULL, 'Poison Point', 'Rivalry', 'Hustle', 61, 72, 57, 55, 55, 65),
(034, 'Nidoking', 'Ground', 'Poison Point', 'Rivalry', 'Rivalry', 'Sheer Force', 81, 102, 77, 85, 75, 85),
(035, 'Clefairy', 'Fairy', NULL, 'Cute Charm', 'Magic Guard', 'Friend Guard', 70, 45, 48, 60, 65, 35),
(036, 'Clefable', 'Fairy', NULL, 'Cute Charm', 'Magic Guard', 'Friend Guard', 95, 70, 73, 95, 90, 60),
(037, 'Vulpix', 'Fire', NULL, 'Flash Fire', 'Drought', NULL, 38, 41, 40, 50, 65, 65),
(038, 'Ninetales', 'Fire', NULL, 'Flash Fire', 'Drought', NULL, 73, 76, 75, 81, 100, 100),
(039, 'Jigglypuff', 'Normal', 'Fairy', 'Cute Charm', 'Competitive', 'Friend Guard', 115, 45, 20, 45, 25, 20),
(040, 'Wigglytuff', 'Normal', 'Fairy', 'Cute Charm', 'Competitive', 'Frisk', 140, 70, 45, 85, 50, 45),
(041, 'Zubat', 'Poison', 'Flying', 'Inner Focus', 'Infiltrator', NULL, 40, 45, 35, 30, 40, 55),
(042, 'Golbat', 'Poison', 'Flying', 'Inner Focus', 'Infiltrator', NULL, 75, 80, 70, 65, 75, 90),
(043, 'Oddish', 'Grass', 'Poison', 'Chlorophyll', 'Run Away', NULL, 45, 50, 55, 75, 65, 30),
(044, 'Gloom', 'Grass', 'Poison', 'Chlorophyll', 'Stench', NULL, 60, 65, 70, 85, 75, 40),
(045, 'Vileplume', 'Grass', 'Poison', 'Chlorophyll', 'Effect Spore', NULL, 75, 80, 85, 110, 90, 50),
(046, 'Paras', 'Bug', 'Grass', 'Effect Spore', 'Dry Skin', 'Damp', 35, 70, 55, 45, 55, 25),
(047, 'Parasect', 'Bug', 'Grass', 'Effect Spore', 'Dry Skin', 'Damp', 60, 95, 80, 60, 80, 30),
(048, 'Venonat', 'Bug', 'Poison', 'Compoundeyes', 'Tinted Lens', 'Run Away', 60, 55, 50, 40, 55, 45),
(049, 'Venomoth', 'Bug', 'Poison', 'Shield Dust', 'Tinted Lens', 'Wonder Skin', 70, 65, 60, 90, 75, 90),
(050, 'Diglett', 'Ground', NULL, 'Sand Veil', 'Arena Trap', 'Sand Force', 10, 55, 25, 35, 45, 95),
(051, 'Dugtrio', 'Ground', NULL, 'Sand Veil', 'Arena Trap', 'Sand Force', 35, 100, 50, 50, 70, 120),
(052, 'Meowth', 'Normal', NULL, 'Pickup', 'Technician', 'Unnerve', 40, 45, 35, 40, 40, 90),
(053, 'Persian', 'Normal', NULL, 'Limber', 'Technician', 'Unnerve', 65, 70, 60, 65, 65, 115),
(054, 'Psyduck', 'Water', NULL, 'Damp', 'Cloud Nine', 'Swift Swim', 50, 52, 48, 65, 50, 55),
(055, 'Golduck', 'Water', NULL, 'Damp', 'Cloud Nine', 'Swift Swim', 80, 82, 78, 95, 80, 85),
(056, 'Mankey', 'Fighting', NULL, 'Vital Spirit', 'Anger Point', 'Defiant', 40, 80, 35, 35, 45, 70),
(057, 'Primeape', 'Fighting', NULL, 'Vital Spirit', 'Anger Point', 'Defiant', 65, 105, 60, 60, 70, 95),
(058, 'Growlithe', 'Fire', NULL, 'Intimidate', 'Flash Fire', 'Justified', 55, 70, 45, 70, 50, 60),
(059, 'Arcanine', 'Fire', NULL, 'Intimidate', 'Flash Fire', 'Justified', 90, 110, 80, 100, 80, 95),
(060, 'Poliwag', 'Water', NULL, 'Water Absorb', 'Damp', 'Swift Swim', 40, 50, 40, 40, 40, 90),
(061, 'Poliwhirl', 'Water', NULL, 'Water Absorb', 'Damp', 'Swift Swim', 65, 65, 65, 50, 50, 90),
(062, 'Poliwrath', 'Water', 'Fighting', 'Water Absorb', 'Damp', 'Swift Swim', 90, 95, 95, 70, 90, 70),
(063, 'Abra', 'Psychic', NULL, 'Synchronize', 'Inner Focus', 'Magic Guard', 25, 20, 15, 105, 55, 90),
(064, 'Kadabra', 'Psychic', NULL, 'Synchronize', 'Inner Focus', 'Magic Guard', 40, 35, 30, 120, 70, 105),
(065, 'Alakazam', 'Psychic', NULL, 'Synchronize', 'Inner Focus', 'Magic Guard', 55, 50, 45, 135, 95, 120),
(066, 'Machop', 'Fighting', NULL, 'Guts', 'No Guard', 'Steadfast', 70, 80, 50, 35, 35, 35),
(067, 'Machoke', 'Fighting', NULL, 'Guts', 'No Guard', 'Steadfast', 80, 100, 70, 50, 60, 45),
(068, 'Machamp', 'Fighting', NULL, 'Guts', 'No Guard', 'Steadfast', 90, 130, 80, 65, 85, 55),
(069, 'Bellsprout', 'Grass', 'Poison', 'Chlorophyll', 'Gluttony', NULL, 50, 75, 35, 70, 30, 40),
(070, 'Weepinbell', 'Grass', 'Poison', 'Chlorophyll', 'Gluttony', NULL, 65, 90, 50, 85, 45, 55),
(071, 'Victreebel', 'Grass', 'Poison', 'Chlorophyll', 'Gluttony', NULL, 80, 105, 65, 100, 70, 70),
(072, 'Tentacool', 'Water', 'Poison', 'Clear Body', 'Liquid Ooze', 'Rain Dish', 40, 40, 35, 50, 100, 70),
(073, 'Tentacruel', 'Water', 'Poison', 'Clear Body', 'Liquid Ooze', 'Rain Dish', 80, 70, 65, 80, 120, 100),
(074, 'Geodude', 'Rock', 'Ground', 'Rock Head', 'Sturdy', 'Sand Veil', 40, 80, 100, 30, 30, 20),
(075, 'Graveler', 'Rock', 'Ground', 'Rock Head', 'Sturdy', 'Sand Veil', 55, 95, 115, 45, 45, 35),
(076, 'Golem', 'Rock', 'Ground', 'Rock Head', 'Sturdy', 'Sand Veil', 80, 120, 130, 55, 65, 45),
(077, 'Ponyta', 'Fire', NULL, 'Run Away', 'Flash Fire', 'Flame Body', 50, 85, 55, 65, 65, 90),
(078, 'Rapidash', 'Fire', NULL, 'Run Away', 'Flash Fire', 'Flame Body', 65, 100, 70, 80, 80, 105),
(079, 'Slowpoke', 'Water', 'Psychic', 'Oblivious', 'Own Tempo', 'Regenerator', 90, 65, 65, 40, 40, 15),
(080, 'Slowbro', 'Water', 'Psychic', 'Oblivious', 'Own Tempo', 'Regenerator', 95, 75, 110, 100, 80, 30),
(081, 'Magnemite', 'Electric', 'Steel', 'Magnet Pull', 'Sturdy', 'Analytic', 25, 35, 70, 95, 55, 45),
(082, 'Magneton', 'Electric', 'Steel', 'Magnet Pull', 'Sturdy', 'Analytic', 50, 60, 95, 120, 70, 70),
(083, 'Farfetch`d', 'Normal', 'Flying', 'Keen Eye', 'Inner Focus', 'Defiant', 52, 90, 55, 58, 62, 60),
(084, 'Doduo', 'Normal', 'Flying', 'Run Away', 'Early Bird', 'Tangled Feet', 35,	85,	45,	35,	35,	75),
(085, 'Dodrio', 'Normal', 'Flying', 'Run Away', 'Early Bird', 'Tangled Feet', 60, 110, 70, 60, 60, 110),
(086, 'Seel', 'Water', NULL, 'Thick Fat', 'Hydration', 'Ice Body', 65, 45, 55, 45, 70, 45),
(087, 'Dewgong', 'Water', 'Ice', 'Thick Fat', 'Hydration', 'Ice Body', 90, 70, 80, 70, 95, 70),
(088, 'Grimer', 'Poison', NULL, 'Stench', 'Sticky Hold', 'Poison Touch', 80,	80,	50,	40,	50,	25),
(089, 'Muk', 'Poison', NULL, 'Stench', 'Sticky Hold', 'Poison Touch', 105, 105, 75, 65, 100, 50),
(090, 'Shellder', 'Water', NULL, 'Shell Armor', 'Skill Link', 'Overcoat', 30, 65, 100, 45, 25, 40),
(091, 'Cloyster', 'Water', 'Ice', 'Shell Armor', 'Skill Link', 'Overcoat', 50, 95, 180, 85, 45, 70),
(092, 'Gastly', 'Ghost', 'Poison', 'Levitate', NULL, NULL, 30, 35, 30, 100, 35, 80),
(093, 'Haunter', 'Ghost', 'Poison', 'Levitate', NULL, NULL, 45, 50, 45, 115, 55, 95),
(094, 'Gengar', 'Ghost', 'Poison', 'Cursed Body', NULL, NULL, 60, 65, 60, 130, 75, 110),
(095, 'Onix', 'Rock', 'Ground', 'Rock Head', 'Sturdy', 'Weak Armor', 35,	45,	160, 30, 45, 70),
(096, 'Drowzee', 'Psychic', NULL, 'Insomnia', 'Forewarn', 'Inner Focus', 60,	48,	45,	43,	90,	42),
(097, 'Hypno', 'Psychic', NULL, 'Insomnia', 'Forewarn', 'Inner Focus', 85, 73, 70, 73, 115, 67),
(098, 'Krabby', 'Water', NULL, 'Hyper Cutter', 'Shell Armor', 'Sheer Force', 30,	105, 90, 25, 25, 50),
(099, 'Kingler', 'Water', NULL, 'Hyper Cutter', 'Shell Armor', 'Sheer Force', 55, 130, 115, 50, 50, 75),
(100, 'Voltorb', 'Electric', NULL, 'Soundproof', 'Static', 'Aftermath', 40,	30,	50,	55,	55,	100),
(101, 'Electrode', 'Electric', NULL, 'Soundproof', 'Static', 'Aftermath', 60, 50, 70, 80, 80, 150),
(102, 'Exeggcute', 'Grass', 'Psychic', 'Chlorophyll', 'Harvest', NULL, 60, 40, 80, 60, 45, 40),
(103, 'Exeggutor', 'Grass', 'Psychic', 'Chlorophyll', 'Harvest', NULL, 95, 95, 85, 125, 75, 55),
(104, 'Cubone', 'Ground', NULL, 'Rock Head', 'Lightning Rod', 'Battle Armor', 50, 50, 95, 40, 50, 35),
(105, 'Marowak', 'Ground', NULL, 'Rock Head', 'Lightning Rod', 'Battle Armor', 60, 80, 110, 50, 80, 45),
(106, 'Hitmonlee', 'Fight', NULL, 'Limber', 'Reckless', 'Unburden', 50, 120, 53, 35, 110, 87),
(107, 'Hitmonchan', 'Fight', NULL, 'Keen Eye', 'Iron Fist', 'Inner Focus', 50, 105, 79, 35, 110, 76),
(108, 'Lickitung', 'Normal', NULL, 'Own Tempo', 'Oblivious', 'Cloud Nine', 90, 55, 75, 60, 75, 30),
(109, 'Koffing', 'Poison', NULL, 'Levitate', 'Neutralizing Gas', 'Stench', 40, 65, 95, 60, 45, 35),
(110, 'Weezing', 'Poison', NULL, 'Levitate', 'Neutralizing Gas', 'Stench', 65, 90, 120, 85, 70, 60),
(111, 'Rhyhorn', 'Ground', 'Rock', 'Lightning Rod', 'Rock Head', 'Reckless', 80, 85, 95, 30, 30, 25),
(112, '	Rhydon', 'Ground', 'Rock', 'Lightning Rod', 'Rock Head', 'Reckless', 105, 130, 120, 45, 45, 40),
(113, 'Chansey', 'Normal', NULL, 'Natural Cure', 'Serene Grace', 'Healer', 250, 5, 5, 35, 105, 50),
(114, '	Tangela', 'Grass', NULL, 'Chlorophyll', 'Leaf Guard', 'Regenerator', 65, 55, 115, 100, 40, 60),
(115, 'Kangaskhan', 'Normal',NULL, 'Early Bird', 'Scrappy','Inner Focus', 45, 49, 49, 65, 65, 45),
(116, 'Horsea', 'Water', NULL, 'Swift Swim', 'Sniper','Damp', 30, 40, 70, 70, 25, 60),
(117, 'Seadra', 'Water', NULL, 'Poison Point', 'Sniper','Damp', 55, 65, 95, 95, 45, 85),
(118, 'Goldeen', 'Water', NULL, 'Swift Swim', 'Water Veil','Lighting Rod', 45, 67, 60, 35, 50, 63),
(119, 'Seaking', 'Water', NULL,'Swift Swim', 'Water Veil','Lighting Rod', 80, 92, 65, 65, 80, 68),
(120, 'Staryu', 'Water', NULL,'Illuminate', 'Natural Cure','Analytic', 30, 45, 55, 70, 55, 85),
(121, 'Starmie', 'Water','Psychic', 'Illuminate', 'Natural Cure','Analytic', 60, 75, 85, 100, 85, 115),
(122, 'Mr. Mime', 'Psychic','Fairy', 'Soundproof', 'Filter','Technician', 40, 45, 65, 100, 120, 90),
(123, 'Scyther', 'Bug','Flying', 'Swarm', 'Technician','Steadfast', 70, 110, 80, 55, 80, 105),
(124, 'Jynx', 'Ice', 'Psychic', 'Oblivious', 'Forewarn', 'Dry Skin', 65, 50, 35, 115, 95, 95),
(125, 'Electabuzz', 'Electric', NULL, 'Static', 'Vital Spirit',NULL, 65, 83, 57, 95, 85, 105),
(126, 'Magmar', 'Fire',NULL, 'Flame Body', 'Vital Spirit', NULL, 65, 95, 57, 100, 85, 93),
(127, 'Pinsir', 'Bug', NULL, 'Hyper Cutter', 'Mold Breaker','Moxie', 65, 125, 100, 55, 70, 85),
(128, 'Tauros', 'Normal',NULL, 'Intimidate', 'Anger Point','Sheer Force', 75, 100, 95, 40, 70, 110),
(129, 'Magikarp', 'Water', NULL, 'Swift Swim', 'Rattled',NULL, 20, 10, 55, 15, 20, 80),
(130, 'Gyarados', 'Water','Flying', 'Intimidate', 'Moxie', NULL, 95, 125, 79, 60, 100, 81),
(131, 'Lapras', 'Water','Ice', 'Water Absorb', 'Shell Armor','Hydration', 130, 85, 80, 85, 95, 60),
(132, 'Ditto', 'Normal', NULL, 'Limber', 'Imposter',NULL, 48, 48, 48, 48, 48, 48),
(133, 'Eevee', 'Normal',NULL, 'Run Away', 'Adaptability', 'Anticipation', 55, 55, 50, 45, 65, 55),
(134, 'Vaporeon', 'Water',NULL, 'Water Absorb', 'Hydration',NULL, 130, 65, 60, 110, 95, 65),
(135, 'Jolteon', 'Electric',NULL,'Volt Absorb', 'Quick Feet', NULL, 65, 65, 60, 110, 95, 130),
(136, 'Flareon', 'Fire', NULL, 'Flash Fire', 'Guts',NULL, 65, 130, 60, 95, 110, 65),
(137, 'Porygon', 'Normal',NULL, 'Trace', 'Download','Analytic', 65, 60, 70, 85, 75, 40),
(138, 'Omanyte', 'Rock','Water', 'Swift Swim', 'Shell Armor','Weak Amour', 35, 40, 100, 90, 55, 35),
(139, 'Omastar', 'Rock','Water', 'Swift Swim', 'Shell Armor','Weak Amour', 70, 60, 125, 115, 70, 55),
(140, 'Kabuto', 'Rock','Water', 'Swift Swim', 'Battle Armor','Weak Amour', 30, 80, 90, 55, 45, 55),
(141, 'Kabutops', 'Rock','Water', 'Swift Swim', 'Battle Armor','Weak Amour', 60, 115, 105, 65, 70, 80),
(142, 'Aerodactyl', 'Rock','Flying','Rock Head', 'Pressure', 'Unnerve', 80, 105, 65, 60, 75, 130),
(143, 'Snorlax', 'Normal',NULL, 'Immunity', 'Thick Fat','Gluttony', 160, 110, 65, 65, 110, 30),
(144, 'Articuno', 'Ice','Flying', 'Pressure', 'Snow Cloak',NULL, 90, 85, 100, 95, 125, 85),
(145, 'Zapdos', 'Electric','Flying', 'Pressure', 'Static',NULL, 90, 90, 85, 125, 90, 100),
(146, 'Moltres', 'Fire','Flying', 'Pressure', 'Flame Body',NULL, 90, 100, 90, 125, 85, 90),
(147, 'Dratini', 'Dragon',NULL, 'Shed Skin', 'Marvel Scale',NULL, 41, 64, 45, 50, 50, 50),
(148, 'Dragonair', 'Dragon', NULL,'Shed Skin', 'Marvel Scale',NULL, 61, 84, 65, 70, 70, 70),
(149, 'Dragonite', 'Dragon','Flying', 'Inner Focus', 'Multiscale',NULL, 91, 134, 95, 100, 100, 80),
(150, 'Mewtwo', 'Psychic',NULL, 'Pressure', 'Unnerve',NULL, 106, 110, 90, 154, 90, 130),
(151, 'Mew', 'Psychic',NULL, 'Synchronize', NULL,NULL, 100, 100, 100, 100, 100, 100);
-- Out:
-- (151 rows affected)
-- Total execution time: 00:00:00.112
