-- %%
-- 1. Connect to Azure SQL Database, master database
USE master; -- used only as a test; will fail if not connected to master

-- 2. Run following database already exists, otherwise skip
DROP DATABASE PokemonGen3; 
GO

-- 3. Run the following code to create an empty database
CREATE DATABASE PokemonGen3;
GO

-- 4. Connect to database before running the rest of the code
USE PokemonGen3; -- used only as a test; will fail if not connected
GO

-- 5. Proceed to section

CREATE TABLE PokemonGen3 (
    PokemonNoGen3 INT PRIMARY KEY,
    Name VARCHAR(50),
    Type VARCHAR(50),
    Type2 VARCHAR(50),
    Ability1 VARCHAR(50),
    Ability2 VARCHAR(50),
    Ability3 VARCHAR(50),
    HP INT,
    Attack INT,
    Defense INT,
    SpecialAttack INT,
    SpecialDefense INT,
    Speed INT
);

INSERT INTO PokemonGen3 
(PokemonNoGen3, Name, Type1, Type2, Ability1, Ability2, Ability3, HP, Attack, Defense, SpecialAttack, SpecialDefense, Speed) VALUES 
(252, 'Treecko', 'Grass', NULL, 'Overgrow', 'Unburden', NULL, 40, 45, 35, 65, 55, 70),
(253, 'Grovyle', 'Grass', NULL, 'Overgrow', 'Unburden', NULL, 50, 65, 45, 85, 65, 95),
(254, 'Sceptile', 'Grass', NULL, 'Overgrow', 'Unburden', NULL, 70, 85, 65, 105, 85, 120),
(255, 'Torchic', 'Fire', NULL, 'Blaze', 'Speed Boost', NULL, 45, 60, 40, 70, 50, 45),
(256, 'Combusken', 'Fire', NULL, 'Blaze', 'Speed Boost', NULL, 60, 85, 60, 85, 60, 55),
(257, 'Blaziken', 'Fire', NULL, 'Blaze', 'Speed Boost', NULL, 80, 120, 70, 110, 70, 80),
(258, 'Mudkip', 'Water', NULL, 'Torrent', 'Damp', NULL, 50, 70, 50, 50, 50, 40),
(259, 'Marshtomp', 'Water', NULL, 'Torrent', 'Damp', NULL, 70, 85, 70, 60, 70, 50),
(260, 'Swampert', 'Water', NULL, 'Torrent', 'Damp', NULL, 100, 110, 90, 85, 90, 60),
(261, 'Poochyena', 'Dark', NULL, 'Run Away', 'Quick Feet', 'Rattled', 35, 55, 35, 30, 30, 35),
(262, 'Mightyena', 'Dark', NULL, 'Intimidate', 'Quick Feet', 'Moxie', 70, 90, 70, 60, 60, 70),
(263, 'Zigzagoon', 'Normal', NULL, 'Pickup', 'Gluttony', 'Quick Feet', 38, 30, 41, 30, 41, 60),
(264, 'Linoone', 'Normal', NULL, 'Pickup', 'Gluttony', 'Quick Feet', 78, 70, 61, 50, 61, 100),
(265, 'Wurmple', 'Bug', NULL, 'Shield Dust', 'Run Away', NULL, 45, 45, 35, 20, 30, 20),
(266, 'Silcoon', 'Bug', NULL, 'Shed Skin', NULL, NULL, 50, 35, 55, 25, 25, 15),
(267, 'Beautifly', 'Bug', 'Flying', 'Swarm', 'Rivalry', NULL, 60, 70, 50, 100, 50, 65),
(268, 'Cascoon', 'Bug', NULL, 'Shed Skin', NULL, NULL, 50, 35, 55, 25, 25, 15),
(269, 'Dustox', 'Bug', 'Poison', 'Shield Dust', 'Compoundeyes', NULL, 60, 50, 70, 50, 90, 65),
(270, 'Lotad', 'Water', 'Grass', 'Swift Swim', 'Rain Dish', 'Own Tempo', 40, 30, 30, 40, 50, 30),
(271, 'Lombre', 'Water', 'Grass', 'Swift Swim', 'Rain Dish', 'Own Tempo', 60, 50, 50, 60, 70, 50),
(272, 'Ludicolo', 'Water', 'Grass', 'Swift Swim', 'Rain Dish', 'Own Tempo', 80, 70, 70, 90, 100, 70),
(273, 'Seedot', 'Grass', NULL, 'Chlorophyll', 'Early Bird', 'Pickpocket', 40, 40, 50, 30, 30, 30),
(274, 'Nuzleaf', 'Grass', 'Dark', 'Chlorophyll', 'Early Bird', 'Pickpocket', 70, 70, 40, 60, 40, 60),
(275, 'Shiftry', 'Grass', 'Dark', 'Chlorophyll', 'Wind Rider', 'Pickpocket', 90, 100, 60, 90, 60, 80),
(276, 'Taillow', 'Normal', 'Flying', 'Guts', 'Scrappy', NULL, 40, 55, 30, 30, 30, 85),
(277, 'Swellow', 'Normal', 'Flying', 'Guts', 'Scrappy', NULL, 60, 85, 60, 75, 50, 125),
(278, 'Wingull', 'Water', 'Flying', 'Keen Eye', 'Hydration', 'Rain Dish', 40, 30, 30, 55, 30, 85),
(279, 'Pelipper', 'Water', 'Flying', 'Keen Eye', 'Drizzle', 'Rain Dish', 60, 50, 100, 95, 70, 65),
(280, 'Ralts', 'Psychic', 'Fairy', 'Synchronize', 'Trace', 'Telepathy', 28, 25, 25, 45, 35, 40),
(281, 'Kirlia', 'Psychic', 'Fairy', 'Synchronize', 'Trace', 'Telepathy', 38, 35, 35, 65, 55, 50),
(282, 'Gardevoir', 'Psychic', 'Fairy', 'Synchronize', 'Trace', 'Telepathy', 68, 65, 65, 125, 115, 80),
(283, 'Surskit', 'Bug', 'Water', 'Swift Swim', 'Rain Dish', NULL, 40, 30, 32, 50, 52, 65),
(284, 'Masquerain', 'Bug', 'Flying', 'Intimidate', 'Unnerve', NULL, 70, 60, 62, 100, 82, 80),
(285, 'Shroomish', 'Grass', NULL, 'Effect Spore', 'Poison Heal', 'Quick Feet', 60, 40, 60, 40, 60, 35),
(286, 'Breloom', 'Grass', 'Fighting', 'Effect Spore', 'Poison Heal', 'Technician', 60, 130, 80, 60, 60, 70),
(287, 'Slakoth', 'Normal', NULL, 'Truant', NULL, NULL, 60, 60, 60, 35, 35, 30),
(288, 'Vigoroth', 'Normal', NULL, 'Vital Spirit', NULL, NULL, 80, 80, 80, 55, 55, 90),
(289, 'Slaking', 'Normal', NULL, 'Truant', NULL, NULL, 150, 160, 100, 95, 65, 100),
(290, 'Nincada', 'Bug', 'Ground', 'Compoundeyes', 'Run Away', NULL, 31, 45, 90, 30, 30, 40),
(291, 'Ninjask', 'Bug', 'Flying', 'Speed Boost', 'Infiltrator', NULL, 61, 90, 45, 50, 50, 160),
(292, 'Shedinja', 'Bug', 'Ghost', 'Wonder Guard', NULL, NULL, 1, 90, 45, 30, 30, 40),
(293, 'Whismur', 'Normal', NULL, 'Soundproof', 'Rattled', NULL, 64, 51, 23, 51, 23, 28),
(294, 'Loudred', 'Normal', NULL, 'Soundproof', 'Scrappy', NULL, 84, 71, 43, 71, 43, 48),
(295, 'Exploud', 'Normal', NULL, 'Soundproof', 'Scrappy', NULL, 104, 91, 63, 91, 73, 68),
(296, 'Makuhita', 'Fighting', NULL, 'Thick Fat', 'Guts', 'Sheer Force', 72, 60, 30, 20, 30, 25),
(297, 'Hariyama', 'Fighting', NULL, 'Thick Fat', 'Guts', 'Sheer Force', 144, 120, 60, 40, 60, 50),
(298, 'Azurill', 'Normal', 'Fairy', 'Thick Fat', 'Huge Power', 'Sap Sipper', 50, 20, 40, 20, 40, 20),
(299, 'Nosepass', 'Rock', NULL, 'Sturdy', 'Magnet Pull', 'Sand Force', 30, 45, 135, 45, 90, 30),
(300, 'Skitty', 'Normal', NULL, 'Cute Charm', 'Normalize', 'Wonder Skin', 50, 45, 45, 35, 35, 50),
(301, 'Delcatty', 'Normal', NULL, 'Cute Charm', 'Normalize', 'Wonder Skin', 70, 65, 65, 55, 55, 90),
(302, 'Sableye', 'Dark', 'Ghost', 'Keen Eye', 'Stall', 'Prankster', 50, 75, 75, 65, 65, 50),
(303, 'Mawile', 'Steel', 'Fairy', 'Hyper Cutter', 'Intimidate', 'Sheer Force', 50, 85, 85, 55, 55, 50),
(304, 'Aron', 'Steel', 'Rock', 'Sturdy', 'Rock Head', 'Heavy Metal', 50, 70, 100, 40, 40, 30),
(305, 'Lairon', 'Steel', 'Rock', 'Sturdy', 'Rock Head', 'Heavy Metal', 60, 90, 140, 50, 50, 40),
(306, 'Aggron', 'Steel', 'Rock', 'Sturdy', 'Rock Head', 'Heavy Metal', 70, 110, 180, 60, 60, 50),
(307, 'Meditite', 'Fighting', 'Psychic', 'Pure Power', 'Telepathy', NULL, 30, 40, 55, 40, 55, 60),
(308, 'Medicham', 'Fighting', 'Psychic', 'Pure Power', 'Telepathy', NULL, 60, 60, 75, 60, 75, 80),
(309, 'Electrike', 'Electric', NULL, 'Static', 'Lightning Rod', 'Minus', 40, 45, 40, 65, 40, 65),
(310, 'Manectric', 'Electric', NULL, 'Static', 'Lightning Rod', 'Minus', 70, 75, 60, 105, 60, 105),
(311, 'Plusle', 'Electric', NULL, 'Plus', 'Lightning Rod', NULL, 60, 50, 40, 85, 75, 95),
(312, 'Minun', 'Electric', NULL, 'Minus', 'Volt Absorb', NULL, 60, 40, 50, 75, 85, 95),
(313, 'Volbeat', 'Bug', NULL, 'Illuminate', 'Swarm', 'Prankster', 65, 73, 75, 47, 85, 85),
(314, 'Illumise', 'Bug', NULL, 'Oblivious', 'Tinted Lens', 'Prankster', 65, 47, 75, 73, 85, 85),
(315, 'Roselia', 'Grass', 'Poison', 'Natural Cure', 'Poison Point', 'Leaf Guard', 50, 60, 45, 100, 80, 65),
(316, 'Gulpin', 'Poison', NULL, 'Liquid Ooze', 'Sticky Hold', 'Gluttony', 70, 43, 53, 43, 53, 40),
(317, 'Swalot', 'Poison', NULL, 'Liquid Ooze', 'Sticky Hold', 'Gluttony', 100, 73, 83, 73, 83, 55),
(318, 'Carvanha', 'Water', 'Dark', 'Rough Skin', 'Speed Boost', NULL, 45, 90, 20, 65, 20, 65),
(319, 'Sharpedo', 'Water', 'Dark', 'Rough Skin', 'Speed Boost', NULL, 70, 120, 40, 95, 40, 95),
(320, 'Wailmer', 'Water', NULL, 'Water Veil', 'Oblivious', 'Pressure', 130, 70, 35, 70, 35, 60),
(321, 'Wailord', 'Water', NULL, 'Water Veil', 'Oblivious', 'Pressure', 170, 90, 45, 90, 45, 60),
(322, 'Numel', 'Fire', 'Ground', 'Oblivious', 'Simple', 'Own Tempo', 60, 60, 40, 65, 45, 35),
(323, 'Camerupt', 'Fire', 'Ground', 'Magma Armor', 'Solid Rock', 'Anger Point', 70, 100, 70, 105, 75, 40),
(324, 'Torkoal', 'Fire', NULL, 'White Smoke', 'Drought', 'Shell Armor', 70, 85, 140, 85, 70, 20),
(325, 'Spoink', 'Psychic', NULL, 'Thick Fat', 'Own Tempo', 'Gluttony', 60, 25, 35, 70, 80, 60),
(326, 'Grumpig', 'Psychic', NULL, 'Thick Fat', 'Own Tempo', 'Gluttony', 80, 45, 65, 90, 110, 80),
(327, 'Spinda', 'Normal', NULL, 'Own Tempo', 'Tangled Feet', 'Contrary', 60, 60, 60, 60, 60, 60),
(328, 'Trapinch', 'Ground', NULL, 'Hyper Cutter', 'Arena Trap', 'Sheer Force', 45, 100, 45, 45, 45, 10),
(329, 'Vibrava', 'Ground', 'Dragon', 'Levitate', NULL, NULL, 50, 70, 50, 50, 50, 70),
(330, 'Flygon', 'Ground', 'Dragon', 'Levitate', NULL, NULL, 80, 100, 80, 80, 80, 100),
(331, 'Cacnea', 'Grass', NULL, 'Sand Veil', 'Water Absorb', NULL, 50, 85, 40, 85, 40, 35),
(332, 'Cacturne', 'Grass', 'Dark', 'Sand Veil', 'Water Absorb', NULL, 70, 115, 60, 115, 60, 55),
(333, 'Swablu', 'Normal', 'Flying', 'Natural Cure', 'Cloud Nine', NULL, 45, 40, 60, 40, 75, 50),
(334, 'Altaria', 'Dragon', 'Flying', 'Natural Cure', 'Cloud Nine', NULL, 75, 70, 90, 70, 105, 80),
(335, 'Zangoose', 'Normal', NULL, 'Immunity', 'Toxic Boost', NULL, 73, 115, 60, 60, 60, 90),
(336, 'Seviper', 'Poison', NULL, 'Shed Skin', 'Infiltrator', NULL, 73, 100, 60, 100, 60, 65),
(337, 'Lunatone', 'Rock', 'Psychic', 'Levitate', NULL, NULL, 90, 55, 65, 95, 85, 70),
(338, 'Solrock', 'Rock', 'Psychic', 'Levitate', NULL, NULL, 90, 95, 85, 55, 65, 70),
(339, 'Barboach', 'Water', 'Ground', 'Oblivious', 'Anticipation', 'Hydration', 50, 48, 43, 46, 41, 60),
(340, 'Whiscash', 'Water', 'Ground', 'Oblivious', 'Anticipation', 'Hydration', 110, 78, 73, 76, 71, 60),
(341, 'Corphish', 'Water', NULL, 'Hyper Cutter', 'Shell Armor', 'Adaptability', 43, 80, 65, 50, 35, 35),
(342, 'Crawdaunt', 'Water', 'Dark', 'Hyper Cutter', 'Shell Armor', 'Adaptability', 63, 120, 85, 90, 55, 55),
(343, 'Baltoy', 'Ground', 'Psychic', 'Levitate', NULL, NULL, 40, 40, 55, 40, 70, 55),
(344, 'Claydol', 'Ground', 'Psychic', 'Levitate', NULL, NULL, 60, 70, 105, 70, 120, 75),
(345, 'Lileep', 'Rock', 'Grass', 'Suction Cups', 'Storm Drain', NULL, 66, 41, 77, 61, 87, 23),
(346, 'Cradily', 'Rock', 'Grass', 'Suction Cups', 'Storm Drain', NULL, 86, 81, 97, 81, 107, 43),
(347, 'Anorith', 'Rock', 'Bug', 'Battle Armor', 'Swift Swim', NULL, 45, 95, 50, 40, 50, 75),
(348, 'Armaldo', 'Rock', 'Bug', 'Battle Armor', 'Swift Swim', NULL, 75, 125, 100, 70, 80, 45),
(349, 'Feebas', 'Water', NULL, 'Swift Swim', 'Oblivious', 'Adaptability', 20, 15, 20, 10, 55, 80),
(350, 'Milotic', 'Water', NULL, 'Marvel Scale', 'Competitive', 'Cute Charm', 95, 60, 79, 100, 125, 81),
(351, 'Castform', 'Normal', NULL, 'Forecast', NULL, NULL, 70, 70, 70, 70, 70, 70),
(352, 'Kecleon', 'Normal', NULL, 'Color Change', 'Protean', NULL, 60, 90, 70, 60, 120, 40),
(353, 'Shuppet', 'Ghost', NULL, 'Insomnia', 'Frisk', 'Cursed Body', 44, 75, 35, 63, 33, 45),
(354, 'Banette', 'Ghost', NULL, 'Insomnia', 'Frisk', 'Cursed Body', 64, 115, 65, 83, 63, 65),
(355, 'Duskull', 'Ghost', NULL, 'Levitate', 'Frisk', NULL, 20, 40, 90, 30, 90, 25),
(356, 'Dusclops', 'Ghost', NULL, 'Pressure', 'Frisk', NULL, 40, 70, 130, 60, 130, 25),
(357, 'Tropius', 'Grass', 'Flying', 'Chlorophyll', 'Solar Power', 'Harvest', 99, 68, 83, 72, 87, 51),
(358, 'Chimecho', 'Psychic', NULL, 'Levitate', NULL, NULL, 75, 50, 80, 95, 90, 65),
(359, 'Absol', 'Dark', NULL, 'Pressure', 'Super Luck', 'Justified', 65, 130, 60, 75, 60, 75),
(360, 'Wynaut', 'Psychic', NULL, 'Shadow Tag', 'Telepathy', NULL, 95, 23, 48, 23, 48, 23),
(361, 'Snorunt', 'Ice', NULL, 'Inner Focus', 'Ice Body', 'Moody', 50, 50, 50, 50, 50, 50),
(362, 'Glalie', 'Ice', NULL, 'Inner Focus', 'Ice Body', 'Moody', 80, 80, 80, 80, 80, 80),
(363, 'Spheal', 'Ice', 'Water', 'Thick Fat', 'Ice Body', 'Oblivious', 70, 40, 50, 55, 50, 25),
(364, 'Sealeo', 'Ice', 'Water', 'Thick Fat', 'Ice Body', 'Oblivious', 90, 60, 70, 75, 70, 45),
(365, 'Walrein', 'Ice', 'Water', 'Thick Fat', 'Ice Body', 'Oblivious', 110, 80, 90, 95, 90, 65),
(366, 'Clamperl', 'Water', NULL, 'Shell Armor', 'Rattled', NULL, 35, 64, 85, 74, 55, 32),
(367, 'Huntail', 'Water', NULL, 'Swift Swim', 'Water Veil', NULL, 55, 104, 105, 94, 75, 52),
(368, 'Gorebyss', 'Water', NULL, 'Swift Swim', 'Hydration', NULL, 55, 84, 105, 114, 75, 52),
(369, 'Relicanth', 'Water', 'Rock', 'Swift Swim', 'Rock Head', 'Sturdy', 100, 90, 130, 45, 65, 55),
(370, 'Luvdisc', 'Water', NULL, 'Swift Swim', 'Hydration', NULL, 43, 30, 55, 40, 65, 97),
(371, 'Bagon', 'Dragon', NULL, 'Rock Head', 'Sheer Force', NULL, 45, 75, 60, 40, 30, 50),
(372, 'Shelgon', 'Dragon', NULL, 'Rock Head', 'Overcoat', NULL, 65, 95, 100, 60, 50, 50),
(373, 'Salamence', 'Dragon', 'Flying', 'Intimidate', 'Moxie', NULL, 95, 135, 80, 110, 80, 100),
(374, 'Beldum', 'Steel', 'Psychic', 'Clear Body', 'Light Metal', NULL, 40, 55, 80, 35, 60, 30),
(375, 'Metang', 'Steel', 'Psychic', 'Clear Body', 'Light Metal', NULL, 60, 75, 100, 55, 80, 50),
(376, 'Metagross', 'Steel', 'Psychic', 'Clear Body', 'Light Metal', NULL, 80, 135, 130, 95, 90, 70),
(377, 'Regirock', 'Rock', NULL, 'Clear Body', 'Sturdy', NULL, 80, 100, 200, 50, 100, 50),
(378, 'Regice', 'Ice', NULL, 'Clear Body', 'Ice Body', NULL, 80, 50, 100, 100, 200, 50),
(379, 'Registeel', 'Steel', NULL, 'Clear Body', 'Light Metal', NULL, 80, 75, 150, 75, 150, 50),
(380, 'Latias', 'Dragon', 'Psychic', 'Levitate', NULL, NULL, 80, 80, 90, 110, 130, 110),
(381, 'Latios', 'Dragon', 'Psychic', 'Levitate', NULL, NULL, 80, 90, 80, 130, 110, 110),
(382, 'Kyogre', 'Water', NULL, 'Drizzle', NULL, NULL, 100, 100, 90, 150, 140, 90),
(383, 'Groudon', 'Ground', NULL, 'Drought', NULL, NULL, 100, 150, 140, 100, 90, 90),
(384, 'Rayquaza', 'Dragon', 'Flying', 'Air Lock', NULL, NULL, 105, 150, 90, 150, 90, 95),
(385, 'Jirachi', 'Steel', 'Psychic', 'Serene Grace', NULL, NULL, 100, 100, 100, 100, 100, 100),
(386, 'Deoxys', 'Psychic', NULL, 'Pressure', NULL, NULL, 50, 150, 50, 150, 50, 150);
