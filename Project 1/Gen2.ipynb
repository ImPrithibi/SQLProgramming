-- %%
CREATE TABLE PokemonGen2 (
    PokemonNoGen2 INT PRIMARY KEY,
    Name VARCHAR(50),
    Type VARCHAR(50),
    Type2 VARCHAR(50),
    Ability1 VARCHAR(50),
    Ability2 VARCHAR(50),
    Ability3 VARCHAR(50),
    HP INT,
    Attack INT,
    Defense INT,
    SpecialAttack INT,
    SpecialDefense INT,
    Speed INT
);

INSERT INTO PokemonGen2 
(PokemonNoGen2, Name, Type1, Type2, Ability1, Ability2, Ability3, HP, Attack, Defense, SpecialAttack, SpecialDefense, Speed) VALUES 
(152, 'Chikorita', 'Grass', NULL, 'Overgrow', 'Leaf Guard', NULL, 45, 49, 65, 49, 65, 45),
(153, 'Bayleef', 'Grass', NULL, 'Overgrow', 'Leaf Guard', NULL, 60, 62, 80, 63, 80, 60),
(154, 'Meganium', 'Grass', NULL, 'Overgrow', 'Leaf Guard', NULL, 80, 82, 100, 83, 100, 80),
(155, 'Cyndaquil', 'Fire', NULL, 'Blaze', 'Flash Fire', NULL, 39, 52, 43, 60, 50, 65),
(156, 'Quilava', 'Fire', NULL, 'Blaze', 'Flash Fire', NULL, 58, 64, 58, 80, 65, 80),
(157, 'Typhlosion', 'Fire', NULL, 'Blaze', 'Flash Fire', NULL, 78, 84, 78, 109, 85, 100),
(158, 'Totodile', 'Water', NULL, 'Torrent', 'Sheer Force', NULL, 50, 65, 64, 44, 48, 43),
(159, 'Croconaw', 'Water', NULL, 'Torrent', 'Sheer Force', NULL, 65, 80, 80, 59, 63, 58),
(160, 'Feraligatr', 'Water', NULL, 'Torrent', 'Sheer Force', NULL, 85, 105, 100, 79, 83, 78),
(161, 'Sentret', 'Normal', NULL, 'Run Away', 'Keen Eye', 'Frisk', 35, 46, 34, 35, 45, 20),
(162, 'Furret', 'Normal', NULL, 'Run Away', 'Keen Eye', 'Frisk', 85, 76, 64, 45, 55, 90),
(163, 'Hoothoot', 'Normal', 'Flying', 'Insomnia', 'Keen Eye', 'Tinted Lens', 60, 30, 30, 36, 56, 50),
(164, 'Noctowl', 'Normal', 'Flying', 'Insomnia', 'Keen Eye', 'Tinted Lens', 100, 50, 50, 86, 96, 70),
(165, 'Ledyba', 'Bug', 'Flying', 'Swarm', 'Early Bird', 'Rattled', 40, 20, 30, 40, 80, 55),
(166, 'Ledian', 'Bug', 'Flying', 'Swarm', 'Early Bird', 'Iron Fist', 55, 35, 50, 55, 110, 85),
(167, 'Spinarak', 'Bug', 'Poison', 'Swarm', 'Insomnia', 'Sniper', 40, 60, 40, 40, 40, 30),
(168, 'Ariados', 'Bug', 'Poison', 'Swarm', 'Insomnia', 'Sniper', 70, 90, 70, 60, 70, 40),
(169, 'Crobat', 'Poison', 'Flying', 'Inner Focus', 'Infiltrator', NULL, 85, 90, 80, 70, 80, 130),
(170, 'Chinchou', 'Water', 'Electric', 'Volt Absorb', 'Illuminate', 'Water Absorb', 75, 38, 38, 56, 56, 67),
(171, 'Lanturn', 'Water', 'Electric', 'Volt Absorb', 'Illuminate', 'Water Absorb', 125, 58, 58, 76, 76, 67),
(172, 'Pichu', 'Electric', NULL, 'Static', 'Lightning Rod', NULL, 20, 40, 15, 35, 35, 60),
(173, 'Cleffa', 'Fairy', NULL, 'Cute Charm', 'Magic Guard', 'Friend Guard', 50, 25, 28, 45, 55, 15),
(174, 'Igglybuff', 'Normal', 'Fairy', 'Cute Charm', 'Competitive', NULL, 90, 30, 15, 40, 20, 15),
(175, 'Togepi', 'Fairy', NULL, 'Hustle', 'Serene Grace', 'Super Luck', 35, 20, 65, 40, 65, 20),
(176, 'Togetic', 'Fairy', 'Flying', 'Hustle', 'Serene Grace', 'Super Luck', 55, 40, 85, 80, 105, 40),
(177, 'Natu', 'Psychic', 'Flying', 'Synchronize', 'Early Bird', 'Magic Bounce', 40, 50, 45, 70, 45, 70),
(178, 'Xatu', 'Psychic', 'Flying', 'Synchronize', 'Early Bird', 'Magic Bounce', 65, 75, 70, 95, 70, 95),
(179, 'Mareep', 'Electric', NULL, 'Static', 'Plus', NULL, 55, 40, 40, 65, 45, 35),
(180, 'Flaaffy', 'Electric', NULL, 'Static', 'Plus', NULL, 70, 55, 55, 80, 60, 45),
(181, 'Ampharos', 'Electric', NULL, 'Static', 'Plus', NULL, 90, 75, 85, 115, 90, 55),
(182, 'Bellossom', 'Grass', NULL, 'Chlorophyll', 'Healer', NULL, 75, 80, 95, 90, 100, 50),
(183, 'Marill', 'Water', 'Fairy', 'Thick Fat', 'Huge Power', 'Sap Sipper', 70, 20, 50, 20, 50, 40),
(184, 'Azumarill', 'Water', 'Fairy', 'Thick Fat', 'Huge Power', 'Sap Sipper', 100, 50, 80, 60, 80, 50),
(185, 'Sudowoodo', 'Rock', NULL, 'Sturdy', 'Rock Head', 'Rattled', 70, 100, 115, 30, 65, 30),
(186, 'Politoed', 'Water', NULL, 'Water Absorb', 'Damp', 'Drizzle', 90, 75, 75, 90, 100, 70),
(187, 'Hoppip', 'Grass', 'Flying', 'Chlorophyll', 'Leaf Guard', 'Infiltrator', 35, 35, 40, 35, 55, 50),
(188, 'Skiploom', 'Grass', 'Flying', 'Chlorophyll', 'Leaf Guard', 'Infiltrator', 55, 45, 50, 45, 65, 80),
(189, 'Jumpluff', 'Grass', 'Flying', 'Chlorophyll', 'Leaf Guard', 'Infiltrator', 75, 55, 70, 55, 95, 110),
(190, 'Aipom', 'Normal', NULL, 'Run Away', 'Pickup', 'Skill Link', 55, 70, 55, 40, 55, 85),
(191, 'Sunkern', 'Grass', NULL, 'Chlorophyll', 'Solar Power', 'Early Bird', 30, 30, 30, 30, 30, 30),
(192, 'Sunflora', 'Grass', NULL, 'Chlorophyll', 'Solar Power', 'Early Bird', 75, 75, 55, 105, 85, 30),
(193, 'Yanma', 'Bug', 'Flying', 'Speed Boost', 'Compoundeyes', 'Frisk', 65, 65, 45, 75, 45, 95),
(194, 'Wooper', 'Water', 'Ground', 'Damp', 'Water Absorb', 'Unaware', 55, 45, 45, 25, 25, 15),
(195, 'Quagsire', 'Water', 'Ground', 'Damp', 'Water Absorb', 'Unaware', 95, 85, 85, 65, 65, 35),
(196, 'Espeon', 'Psychic', NULL, 'Synchronize', 'Magic Bounce', NULL, 65, 65, 60, 130, 95, 110),
(197, 'Umbreon', 'Dark', NULL, 'Synchronize', 'Inner Focus', NULL, 95, 65, 110, 60, 130, 65),
(198, 'Murkrow', 'Dark', 'Flying', 'Insomnia', 'Super Luck', 'Prankster', 60, 85, 42, 85, 42, 91),
(199, 'Slowking', 'Water', 'Psychic', 'Oblivious', 'Own Tempo', 'Regenerator', 95, 75, 80, 100, 110, 30),
(200, 'Misdreavus', 'Ghost', NULL, 'Levitate', NULL, NULL, 60, 60, 60, 85, 85, 85),
(201, 'Unown', 'Psychic', NULL, 'Levitate', NULL, NULL, 48, 72, 48, 72, 48, 48),
(202, 'Wobbuffet', 'Psychic',NULL, 'Shadow Tag', 'Telepathy', NULL, 190,	33,	58,	33,	58,	33),
(203, 'Girafarig', 'Normal', 'Psychic', 'Inner Focus', 'Early Bird', 'Sap Sipper', 70,	80,	65,	90,	65,	85),
(204, 'Pineco', 'Bug', NULL, 'Sturdy', 'Overcoat', NULL, 50, 65, 90, 35, 35, 15),
(205, 'Forretress', 'Bug', 'Steel', 'Sturdy', 'Overcoat', NULL, 75, 90, 140, 60, 60, 40),
(206, 'Dunsparce', 'Normal', NULL, 'Serene Grace', 'Run Away', 'Rattled', 100, 70, 70, 65, 65, 45),
(207, 'Gligar', 'Ground', 'Flying', 'Hyper Cutter', 'Sand Veil', 'Immunity', 65, 75, 105, 35, 65, 85),
(208, 'Steelix', 'Steel', 'Ground', 'Rock Head', 'Sturdy', 'Sheer Force', 75, 85, 200, 55, 65, 30),
(209, 'Snubbull', 'Fairy', NULL, 'Intimidate', 'Run Away', 'Rattled', 60, 80, 50, 40, 40, 30),
(210, 'Granbull', 'Fairy', NULL, 'Intimidate', 'Quick Feet', 'Rattled', 90, 120, 75, 60, 60, 45),
(211, 'Qwilfish', 'Water', 'Poison', 'Poison Point', 'Swift Swim', 'Intimidate', 65, 95, 85, 55, 55, 85),
(212, 'Scizor', 'Bug', 'Steel', 'Swarm', 'Technician', 'Light Metal', 70, 130, 100, 55, 80, 65),
(213, 'Shuckle', 'Bug', 'Rock', 'Sturdy', 'Gluttony', 'Contrary', 20, 10, 230, 10, 230, 5),
(214, 'Heracross', 'Bug', 'Fighting', 'Swarm', 'Guts', 'Moxie', 80, 125, 75, 40, 95, 85),
(215, 'Sneasel', 'Dark', 'Ice', 'Inner Focus', 'Keen Eye', 'Pickpocket', 55, 95, 55, 35, 75, 115),
(216, 'Teddiursa', 'Normal', NULL, 'Pickup', 'Quick Feet', 'Honey Gather', 60, 80, 50, 50, 50, 40),
(217, 'Ursaring', 'Normal', NULL, 'Guts', 'Quick Feet', 'Unnerve', 90, 130, 75, 75, 75, 55),
(218, 'Slugma', 'Fire', NULL, 'Magma Armor', 'Flame Body', 'Weak Armor', 40, 40, 40, 70, 40, 20),
(219, 'Magcargo', 'Fire', 'Rock', 'Magma Armor', 'Flame Body', 'Weak Armor', 60, 50, 120, 90, 80, 30),
(220, 'Swinub', 'Ice', 'Ground', 'Oblivious', 'Snow Cloak', 'Thick Fat', 50, 50, 40, 30, 30, 50),
(221, 'Piloswine', 'Ice', 'Ground', 'Oblivious', 'Snow Cloak', 'Thick Fat', 100, 100, 80, 60, 60, 50),
(222, 'Corsola', 'Water', 'Rock', 'Hustle', 'Natural Cure', 'Regenerator', 65, 55, 95, 65, 95, 35),
(223, 'Remoraid', 'Water', NULL, 'Hustle', 'Sniper', 'Moody', 35, 65, 35, 65, 35, 65),
(224, 'Octillery', 'Water', NULL, 'Suction Cups', 'Sniper', 'Moody', 75, 105, 75, 105, 75, 45),
(225, 'Delibird', 'Ice', 'Flying', 'Vital Spirit', 'Hustle', 'Insomnia', 45, 55, 45, 65, 45, 75),
(226, 'Mantine', 'Water', 'Flying', 'Swift Swim', 'Water Absorb', 'Water Veil', 85, 40, 70, 80, 140, 70),
(227, 'Skarmory', 'Steel', 'Flying', 'Keen Eye', 'Sturdy', 'Weak Armor', 65, 80, 140, 40, 70, 70),
(228, 'Houndour', 'Dark', 'Fire', 'Early Bird', 'Flash Fire', 'Unnerve', 45, 60, 30, 80, 50, 65),
(229, 'Houndoom', 'Dark', 'Fire', 'Early Bird', 'Flash Fire', 'Unnerve', 75, 90, 50, 110, 80, 95),
(230, 'Kingdra', 'Water', 'Dragon', 'Swift Swim', 'Sniper', 'Damp', 75, 95, 95, 95, 95, 85),
(231, 'Phanpy', 'Ground', NULL, 'Pickup', 'Sand Veil', NULL, 90, 60, 60, 40, 40, 40),
(232, 'Donphan', 'Ground', NULL, 'Sturdy', 'Sand Veil', NULL, 90, 120, 120, 60, 60, 50),
(233, 'Porygon2', 'Normal', NULL, 'Trace', 'Download', 'Analytic', 85, 80, 90, 105, 95, 60),
(234, 'Stantler', 'Normal', NULL, 'Intimidate', 'Frisk', 'Sap Sipper', 73, 95, 62, 85, 65, 85),
(235, 'Smeargle', 'Normal', NULL, 'Own Tempo', 'Technician', 'Moody', 55, 20, 35, 20, 45, 75),
(236, 'Tyrogue', 'Fighting', NULL, 'Guts', 'Steadfast', 'Vital Spirit', 35, 35, 35, 35, 35, 35),
(237, 'Hitmontop', 'Fighting', NULL, 'Intimidate', 'Technician', 'Steadfast', 50, 95, 95, 35, 110, 70),
(238, 'Smoochum', 'Ice', 'Psychic', 'Oblivious', 'Forewarn', 'Hydration', 45, 30, 15, 85, 65, 65),
(239, 'Elekid', 'Electric', NULL, 'Static', 'Vital Spirit', NULL, 45, 63, 37, 65, 55, 95),
(240, 'Magby', 'Fire', NULL, 'Flame Body', 'Vital Spirit', NULL, 45, 75, 37, 70, 55, 83),
(241, 'Miltank', 'Normal', NULL, 'Thick Fat', 'Scrappy', 'Sap Sipper', 95, 80, 105, 40, 70, 100),
(242, 'Blissey', 'Normal', NULL, 'Natural Cure', 'Serene Grace', 'Healer', 255, 10, 10, 75, 135, 55),
(243, 'Raikou', 'Electric', NULL, 'Pressure', 'Inner Focus', NULL, 90, 85, 75, 115, 100, 115),
(244, 'Entei', 'Fire', NULL, 'Pressure', 'Inner Focus', NULL, 115, 115, 85, 90, 75, 100),
(245, 'Suicune', 'Water', NULL, 'Pressure', 'Inner Focus', NULL, 100, 75, 115, 90, 115, 85),
(246, 'Larvitar', 'Rock', 'Ground', 'Guts', 'Sand Veil', NULL, 50, 64, 50, 45, 50, 41),
(247, 'Pupitar', 'Rock', 'Ground', 'Shed Skin', NULL, NULL, 70, 84, 70, 65, 70, 51),
(248, 'Tyranitar', 'Rock', 'Dark', 'Sand Stream', 'Unnerve', NULL, 100, 134, 110, 95, 100, 61),
(249, 'Lugia', 'Psychic', 'Flying', 'Pressure', 'Multiscale', NULL, 106, 90, 130, 90, 154, 110),
(250, 'Ho-Oh', 'Fire', 'Flying', 'Pressure', 'Regenerator', NULL, 106, 130, 90, 110, 154, 90),
(251, 'Celebi', 'Psychic', 'Grass', 'Natural Cure', NULL, NULL, 100, 100, 100, 100, 100, 100);
