-- %% [markdown]
-- **Sabrina Zheng | Group 6 | Chapter 5 Questions 3, 4, 5, 6**
--
-- **Question 3:**
--
-- **\-- 3-1**
--
-- \-- Write a query that calculates a row number for each order
--
-- \-- based on orderdate, orderid ordering
--
-- \-- Tables involved: Sales.Orders
--
-- \-- Desired output:
--
-- orderid     orderdate   custid      empid       rownum
--
-- \----------- ----------- ----------- ----------- -------
--
-- 10248       2020-07-04  85          5           1
--
-- 10249       2020-07-05  79          6           2
--
-- 10250       2020-07-08  34          4           3
--
-- 10251       2020-07-08  84          3           4
--
-- 10252       2020-07-09  76          4           5
--
-- 10253       2020-07-10  34          3           6
--
-- 10254       2020-07-11  14          5           7
--
-- 10255       2020-07-12  68          9           8
--
-- 10256       2020-07-15  88          3           9
--
-- 10257       2020-07-16  35          4           10

-- %%
--Query using TSQLV6 database
USE TSQLV6;

SELECT 
    orderid,
    orderdate,
    custid,
    empid,
    ROW_NUMBER() OVER (ORDER BY orderdate, orderid) AS rownum
FROM 
    Sales.Orders;
-- Out:
-- (830 rows affected)
-- Total execution time: 00:00:00.077
-- ...

-- %% [markdown]
-- **Explanation for the TSQLV6 Query**
--
-- **Proposition:** Calculate a row number for each order based on orderid and order date using the Sales.Orders table.
--
-- **Tables:**
--
-- - Sales.Orders
--
-- **Columns:**
--
-- - orderid
-- - orderdate
-- - custid
-- - empid
--
-- **Predicate:**
--
-- - Retrieves data from Sales.Orders table
-- - Selects the columns orderid, orderdate, custid, and empid.
-- - Uses the ROW\_NUMBER() window function to assign a sequential row number to each row in the result set.
-- - The ROW\_NUMBER() function is ordered by orderdate and orderid in ascending order.

-- %%
-- Query using Northwinds2022TSQLV7 database 
USE Northwinds2022TSQLV7;

SELECT 
    orderid,
    orderdate,
    customerid,
    employeeid,
    ROW_NUMBER() OVER (ORDER BY orderdate, orderid) AS rownum
FROM 
    Sales.[Order];
-- Out:
-- (830 rows affected)
-- Total execution time: 00:00:00.024
-- ...

-- %% [markdown]
-- ### **Explanation for the Northwinds2022TSQLV7 Query**
--
-- **Proposition:** <span style="color: var(--vscode-foreground);">Calculate a row number for each order based on orderid and order date using the Sales.Orders table.</span>
--
-- **Tables:**
--
-- - Sales.\[Order\]
--
-- **Columns:**
--
-- - orderid
-- - orderdate
-- - customerid
-- - emplyeeid
--
-- **Predicate:**
--
-- - ROW\_NUMBER() OVER (ORDER BY orderdate, orderid) AS rownum
--
--  <span style="color: var(--vscode-foreground);">&nbsp;This is a window function that assigns a sequential row number to each row in the result set. The ORDER BY clause within the OVER function specifies the ordering criteria for assigning row numbers. In this case, the rows will be ordered by orderdate first and then by orderid.</span>

-- %% [markdown]
-- **\-- 3-2**
--
-- \-- Write a query that returns rows with row numbers 11 through 20
--
-- \-- based on the row number definition in exercise 3-1
--
-- \-- Use a CTE to encapsulate the code from exercise 3-1
--
-- \-- Tables involved: Sales.Orders
--
-- \-- Desired output:
--
-- orderid     orderdate   custid      empid       rownum
--
-- \----------- ----------- ----------- ----------- -------
--
-- 10258       2020-07-17  20          1           11
--
-- 10259       2020-07-18  13          4           12
--
-- 10260       2020-07-19  56          4           13
--
-- 10261       2020-07-19  61          4           14
--
-- 10262       2020-07-22  65          8           15
--
-- 10263       2020-07-23  20          9           16
--
-- 10264       2020-07-24  24          6           17
--
-- 10265       2020-07-25  7           2           18
--
-- 10266       2020-07-26  87          3           19
--
-- 10267       2020-07-29  25          4           20

-- %%
--Query using TSQLV6 database
USE TSQLV6;

WITH OrderedOrders AS (
    SELECT 
        orderid,
        orderdate,
        custid AS custid,
        empid AS empid,
        ROW_NUMBER() OVER (ORDER BY orderdate, orderid) AS rownum
    FROM 
        Sales.Orders
)

SELECT 
    orderid,
    orderdate,
    custid,
    empid,
    rownum
FROM 
    OrderedOrders
WHERE 
    rownum BETWEEN 11 AND 20;
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.044
-- <table><tr><th>orderid</th><th>orderdate</th><th>custid</th><th>empid</th><th>rownum</th></tr><tr><td>10258</td><td>2020-07-17</td><td>20</td><td>1</td><td>11</td></tr><tr><td>10259</td><td>2020-07-18</td><td>13</td><td>4</td><td>12</td></tr><tr><td>10260</td><td>2020-07-19</td><td>56</td><td>4</td><td>13</td></tr><tr><td>10261</td><td>2020-07-19</td><td>61</td><td>4</td><td>14</td></tr><tr><td>10262</td><td>2020-07-22</td><td>65</td><td>8</td><td>15</td></tr><tr><td>10263</td><td>2020-07-23</td><td>20</td><td>9</td><td>16</td></tr><tr><td>10264</td><td>2020-07-24</td><td>24</td><td>6</td><td>17</td></tr><tr><td>10265</td><td>2020-07-25</td><td>7</td><td>2</td><td>18</td></tr><tr><td>10266</td><td>2020-07-26</td><td>87</td><td>3</td><td>19</td></tr><tr><td>10267</td><td>2020-07-29</td><td>25</td><td>4</td><td>20</td></tr></table>

-- %% [markdown]
-- **Explanation for the TSQLV6 Query**
--
-- **Proposition:** Retrieve a subset of rows from the Sales.Orders table based on the row numbers between 11 and 20 inclusive
--
-- **Tables:**
--
-- - Sales.Orders
--
-- **Columns:**
--
-- - orderid
-- - orderdate
-- - custid
-- - empid
-- - ROW\_NUMBER() OVER (ORDER BY orderdate, orderid) AS rownum
--
-- <span style="color: var(--vscode-foreground);">The ORDER BY clause within the OVER function specifies the ordering criteria for assigning row numbers. In this case, the rows will be ordered by orderdate first and then by orderid.</span>
--
-- **Predicate:**
--
-- - WHERE rownum BETWEEN 11 AND 20
--
-- <span style="color: var(--vscode-foreground);">This&nbsp; filters the rows from the CTE (OrderedOrders) to include only those with row numbers between 11 and 20.</span>

-- %%
-- Query using Northwinds2022TSQLV7 database 
USE Northwinds2022TSQLV7;

WITH OrderedOrders AS (
    SELECT 
        orderid,
        orderdate,
        customerid AS custid,
        employeeid AS empid,
        ROW_NUMBER() OVER (ORDER BY orderdate, orderid) AS rownum
    FROM 
        Sales.[Order]
)

SELECT 
    orderid,
    orderdate,
    custid,
    empid,
    rownum
FROM 
    OrderedOrders
WHERE 
    rownum BETWEEN 11 AND 20;
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.012
-- <table><tr><th>orderid</th><th>orderdate</th><th>custid</th><th>empid</th><th>rownum</th></tr><tr><td>10258</td><td>2014-07-17</td><td>20</td><td>1</td><td>11</td></tr><tr><td>10259</td><td>2014-07-18</td><td>13</td><td>4</td><td>12</td></tr><tr><td>10260</td><td>2014-07-19</td><td>56</td><td>4</td><td>13</td></tr><tr><td>10261</td><td>2014-07-19</td><td>61</td><td>4</td><td>14</td></tr><tr><td>10262</td><td>2014-07-22</td><td>65</td><td>8</td><td>15</td></tr><tr><td>10263</td><td>2014-07-23</td><td>20</td><td>9</td><td>16</td></tr><tr><td>10264</td><td>2014-07-24</td><td>24</td><td>6</td><td>17</td></tr><tr><td>10265</td><td>2014-07-25</td><td>7</td><td>2</td><td>18</td></tr><tr><td>10266</td><td>2014-07-26</td><td>87</td><td>3</td><td>19</td></tr><tr><td>10267</td><td>2014-07-29</td><td>25</td><td>4</td><td>20</td></tr></table>

-- %% [markdown]
-- ### **Explanation for the Northwinds2022TSQLV7 Query**
--
-- **Tables:**
--
-- - Sales.\[Order\]
--
-- **Columns:**
--
-- - orderid
-- - orderdate
-- - customerid
-- - employeeid
--
-- CTE:
--
-- - OrderedOrders
--
-- **Predicate:**
--
-- - CTE OrderedOrders is created, which selects columns orderid, orderdate, customerid (aliased as custid), employeeid (aliased as empid), and calculates the row number using the ROW\_NUMBER() window function. The rows are ordered by orderdate first and then by orderid.
-- - The selected columns (orderid, orderdate, custid, empid, rownum) are retrieved from the CTE OrderedOrders.
-- - <span style="color: var(--vscode-foreground);">A WHERE clause is applied to filter the rows where the rownum is between 11 and 20, inclusive.</span>
-- - The predicate in this query is rownum BETWEEN 11 AND 20, which filters the rows based on the row number calculated in the CTE. It selects rows with row numbers between 11 and 20.

-- %% [markdown]
-- **Question 4:**
--
-- \-- Write a solution using a recursive CTE that returns the
--
-- \-- management chain leading to Patricia Doyle (employee ID 9)
--
-- \-- Tables involved: HR.Employees
--
-- \-- Desired output:
--
-- empid       mgrid       firstname  lastname
--
-- \----------- ----------- ---------- --------------------
--
-- 9           5           Patricia   Doyle
--
-- 5           2           Sven       Mortensen
--
-- 2           1           Don        Funk
--
-- 1           NULL        Sara       Davis

-- %%
--Query using TSQLV6 database
USE TSQLV6;

WITH RecursiveHierarchy AS (
    SELECT 
        empid,
        mgrid,
        firstname,
        lastname
    FROM 
        HR.Employees
    WHERE 
        empid = 9  -- Starting point: Patricia Doyle
    UNION ALL
    SELECT 
        e.empid,
        e.mgrid,
        e.firstname,
        e.lastname
    FROM 
        HR.Employees e
    INNER JOIN 
        RecursiveHierarchy rh ON e.empid = rh.mgrid
)

SELECT 
    empid,
    mgrid,
    firstname,
    lastname
FROM 
    RecursiveHierarchy;
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.016
-- <table><tr><th>empid</th><th>mgrid</th><th>firstname</th><th>lastname</th></tr><tr><td>9</td><td>5</td><td>Patricia</td><td>Doyle</td></tr><tr><td>5</td><td>2</td><td>Sven</td><td>Mortensen</td></tr><tr><td>2</td><td>1</td><td>Don</td><td>Funk</td></tr><tr><td>1</td><td>NULL</td><td>Sara</td><td>Davis</td></tr></table>

-- %% [markdown]
-- **Explanation for the TSQLV6 Query**
--
-- **Proposition:** Return the management chain leading to Patricia Doyle from the HR.Employees table using a recursive CTE
--
-- **Table:**
--
-- - HR.Employees
--
-- **Columns:**
--
-- - empid
-- - mgrid
-- - firstname
-- - lastname
--
-- Recursive CTE:
--
-- - RecursiveHierarchy
--
-- **Predicate:**
--
-- - <span style="color: var(--vscode-foreground);">The recursive CTE RecursiveHierarchy begins by selecting Patricia Doyle (employee ID 9) as the starting point from the HR.Employees table</span>
--
-- - In the recursive part of the CTE, it joins the HR.Employees table with the previous result (RecursiveHierarchy) based on the mgrid column to find the manager of each employee. This continues recursively until no more managers are found.
--
-- - The last SELECT statement retrieves all columns (empid, mgrid, firstname, lastname) from the RecursiveHierarchy, which now contains the entire management chain leading to Patricia Doyle.
--
-- - The CTE (Common Table Expression) recursively navigates the management hierarchy starting from Patricia Doyle (employee ID 9) until reaching the top of the hierarchy where the manager's mgrid is NULL.

-- %%
-- Query using Northwinds2022TSQLV7 database 
USE Northwinds2022TSQLV7;

WITH RecursiveHierarchy AS (
    SELECT 
        employeeid,
        EmployeeManagerId,
        EmployeeFirstName,
        EmployeeLastName
    FROM 
        HumanResources.[Employee]
    WHERE 
        employeeid = 9  -- Starting point: Patricia Doyle
    UNION ALL
    SELECT 
        e.employeeid,
        e.EmployeeManagerId,
        e.EmployeeFirstName,
        e.EmployeeLastName
    FROM 
        HumanResources.[Employee] e
    INNER JOIN 
        RecursiveHierarchy rh ON e.employeeid = rh.EmployeeManagerId
)

SELECT 
    employeeid,
    EmployeeManagerId,
    EmployeeFirstName,
    EmployeeLastName
FROM 
    RecursiveHierarchy;
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.025
-- <table><tr><th>employeeid</th><th>EmployeeManagerId</th><th>EmployeeFirstName</th><th>EmployeeLastName</th></tr><tr><td>9</td><td>5</td><td>Patricia</td><td>Doyle</td></tr><tr><td>5</td><td>2</td><td>Sven</td><td>Mortensen</td></tr><tr><td>2</td><td>1</td><td>Don</td><td>Funk</td></tr><tr><td>1</td><td>NULL</td><td>Sara</td><td>Davis</td></tr></table>

-- %% [markdown]
-- ### **Explanation for the Northwinds2022TSQLV7 Query**
--
-- **Proposition:** <span style="color: var(--vscode-foreground);">Return the management chain leading to Patricia Doyle from the HR.Employees table using a recursive CTE</span>
--
-- **Tables:**
--
-- - HumanResources.\[Employee\]
--
-- HumanResources.Employee: This is the table from which data is being retrieved. It's likely a table named "Employee" in the "HumanResources" schema of the "Northwinds2022TSQLV7" database. This table presumably contains information about employees, including their IDs (employeeid), manager IDs (EmployeeManagerId), first names (EmployeeFirstName), and last names (EmployeeLastName).
--
-- **Columns:**
--
-- - emplyeeid
-- - EmployeeManagerId
-- - EmployeeFirstName
-- - EmployeeLastName
--
-- Recursive CTE:
--
-- - RecursiveHierarchy
--
-- **Predicate:**
--
-- - Recursive CTE RecursiveHierarchy begins by selecting Patricia Doyle (employee ID 9) as the starting point from the HumanResources.Employee table
-- - It joins the HumanResources.Employee table with the previous result based on the EmployeeManagerId column to find the manager of each employee. This process continues recursively until no more managers are found
-- - The last SELECT statement retrieves all columns from the RecursiveHierarchy, which now contains the entire management chain leading to Patricia Doyle

-- %% [markdown]
-- **Question 5:**
--
-- **\-- 5-1**
--
-- \-- Create a view that returns the total qty
--
-- \-- for each employee and year
--
-- \-- Tables involved: Sales.Orders and Sales.OrderDetails
--
--
--
-- \-- Desired output when running:
--
-- \-- SELECT \* FROM  Sales.VEmpOrders ORDER BY empid, orderyear
--
-- empid       orderyear   qty
--
-- \----------- ----------- -----------
--
-- 1           2020        1620
--
-- 1           2021        3877
--
-- 1           2022        2315
--
-- 2           2020        1085
--
-- 2           2021        2604
--
-- 2           2022        2366
--
-- 3           2020        940
--
-- 3           2021        4436
--
-- 3           2022        2476
--
-- 4           2020        2212
--
-- 4           2021        5273
--
-- 4           2022        2313
--
-- 5           2020        778
--
-- 5           2021        1471
--
-- 5           2022        787
--
-- 6           2020        963
--
-- 6           2021        1738
--
-- 6           2022        826
--
-- 7           2020        485
--
-- 7           2021        2292
--
-- 7           2022        1877
--
-- 8           2020        923
--
-- 8           2021        2843
--
-- 8           2022        2147
--
-- 9           2020        575
--
-- 9           2021        955
--
-- 9           2022        1140

-- %%
--Query using TSQLV6 database
USE TSQLV6;
GO

CREATE VIEW Sales.VEmpOrders AS
SELECT O.empid,
    YEAR(O.OrderDate) AS orderyear,
    SUM(OD.qty) AS qty
FROM 
    Sales.Orders AS O
JOIN 
    Sales.OrderDetails OD ON O.OrderID = OD.OrderID
GROUP BY 
    O.empid, YEAR(O.OrderDate);
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.075

-- %%
--Query using TSQLV6 database
USE TSQLV6;

SELECT * FROM  Sales.VEmpOrders ORDER BY empid, orderyear
-- Out:
-- (27 rows affected)
-- Total execution time: 00:00:00.153
-- ...

-- %% [markdown]
-- ### **Explanation for the TSQLV6 Query**
--
-- **Proposition:** Create a view named Sales.VEmpOrder providing a summary of employee orders
--
-- **Tables:**
--
-- - Sales.Orders aliased as O
-- - Sales.OrderDetails aliased as OD
--
-- **Columns:**
--
-- - O.empid
-- - orderyear
-- - qty
--
-- **Predicate:**
--
-- -  Joins Sales.Orders and Sales.OrderDetails on their respective OrderID columns (O.OrderID = OD.OrderID)
-- - It groups the results by O.empid and YEAR(O.OrderDate) to aggregate the quantity of orders for each employee and year
-- - The aggregated result is stored in the view Sales.VEmpOrder

-- %%
-- Query using Northwinds2022TSQLV7 database 
USE Northwinds2022TSQLV7;
GO

CREATE VIEW Sales.VEmpOrders AS
SELECT O.EmployeeId,
    YEAR(O.OrderDate) AS orderyear,
    SUM(OD.Quantity) AS qty
FROM 
    Sales.[Order] AS O
JOIN 
    Sales.[OrderDetail] OD ON O.OrderID = OD.OrderID
GROUP BY 
    O.EmployeeId, YEAR(O.OrderDate);
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.051

-- %%
-- Query using Northwinds2022TSQLV7 database 
USE Northwinds2022TSQLV7;

SELECT * FROM  Sales.[VEmpOrders] ORDER BY employeeid, orderyear
-- Out:
-- (27 rows affected)
-- Total execution time: 00:00:00.030
-- ...

-- %% [markdown]
-- ### **Explanation for the Northwinds2022TSQLV7 Query**
--
-- **Proposition:** Create a view Sales.VEmpOrders that provides a summary of the employee orders with EmployeeId, orderyear, and Quantity
--
-- **Tables:**
--
-- - Sales.\[Order\] aliased as O
-- - Sales.\[OrderDetail\] aliased as OD
--
-- **Columns:**
--
-- - O.EmployeeId
-- - Year{O.OrderDate)
-- - SUM(OD.Quantity)
-- - Sales.\[OrderDetail\]
--
-- **Predicate:**
--
-- -  Joins Sales.\[Order\] and Sales.\[OrderDetail\] on their respective OrderID columns (O.OrderID = OD.OrderID)
-- - Groups the results by O.EmployeeId and YEAR(O.OrderDate) to aggregate the quantity of orders for each employee and year
-- - The result is stored in the view Sales.VEmpOrders.

-- %% [markdown]
-- **\-- 5-2**
--
-- \-- Write a query against Sales.VEmpOrders
--
-- \-- that returns the running qty for each employee and year
--
-- \-- Tables involved: TSQLV6 database, Sales.VEmpOrders view
--
--
--
-- \-- Desired output:
--
-- empid       orderyear   qty         runqty
--
-- \----------- ----------- ----------- -----------
--
-- 1           2020        1620        1620
--
-- 1           2021        3877        5497
--
-- 1           2022        2315        7812
--
-- 2           2020        1085        1085
--
-- 2           2021        2604        3689
--
-- 2           2022        2366        6055
--
-- 3           2020        940         940
--
-- 3           2021        4436        5376
--
-- 3           2022        2476        7852
--
-- 4           2020        2212        2212
--
-- 4           2021        5273        7485
--
-- 4           2022        2313        9798
--
-- 5           2020        778         778
--
-- 5           2021        1471        2249
--
-- 5           2022        787         3036
--
-- 6           2020        963         963
--
-- 6           2021        1738        2701
--
-- 6           2022        826         3527
--
-- 7           2020        485         485
--
-- 7           2021        2292        2777
--
-- 7           2022        1877        4654
--
-- 8           2020        923         923
--
-- 8           2021        2843        3766
--
-- 8           2022        2147        5913
--
-- 9           2020        575         575
--
-- 9           2021        955         1530
--
-- 9           2022        1140        2670

-- %%
--Query using TSQLV6 database
USE TSQLV6;

SELECT 
    empid,
    orderyear,
    qty,
    SUM(qty) OVER (PARTITION BY empid ORDER BY orderyear) AS runqty
FROM 
    Sales.VEmpOrders
ORDER BY 
    empid, orderyear;
-- Out:
-- (27 rows affected)
-- Total execution time: 00:00:00.035
-- ...

-- %% [markdown]
-- **Explanation for the TSQLV6 Query**
--
-- **Proposition:** Retrieve data from the Sales.VEmpOrders view and calculate the runqty for each employee and the year.
--
-- **Table:**
--
-- - Sales.VEmpOrders
--
-- **Columns:**
--
-- - empid
-- - orderyear
-- - qty
-- - runqty
--
-- **Predicate:**
--
-- - SUM(qty) OVER (PARTITION BY empid ORDER BY orderyear)
--
-- <span style="color: var(--vscode-foreground);">This window function calculates the running sum of the qty column partitioned by empid and ordered by orderyear. It calculates the sum of qty for each row, considering only rows with the same empid and rows ordered by orderyear.</span>

-- %%
-- Query using Northwinds2022TSQLV7 database 
USE Northwinds2022TSQLV7;

SELECT 
    EmployeeId,
    orderyear,
    qty,
    SUM(qty) OVER (PARTITION BY employeeid ORDER BY orderyear ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) AS runqty
FROM 
    Sales.[VEmpOrders]
ORDER BY 
    EmployeeId, orderyear;
-- Out:
-- (27 rows affected)
-- Total execution time: 00:00:00.019
-- ...

-- %% [markdown]
-- ### **Explanation for the Northwinds2022TSQLV7 Query**
--
-- **Proposition:** <span style="color: var(--vscode-foreground);">Retrieve data from the Sales.VEmpOrders view and calculate the runqty for each employee and the year.</span>
--
-- **Tables:**
--
-- - Sales.\[VEmpOrders\]
--
-- **Columns:**
--
-- - EmployeeId
-- - orderyear
-- - qty
-- - runqty
--
-- **Predicate:**
--
-- - This query does not directly involve tables or columns. It operates on data already aggregated and provided by the Sales.\[VEmpOrders\] view. It calculates the running total (runqty) without filtering or conditioning the data further.

-- %% [markdown]
-- **Question 6:**
--
-- **\-- 6-1**
--
-- \-- Create an inline function that accepts as inputs
--
-- \-- a supplier id (@supid AS INT),
--
-- \-- and a requested number of products (@n AS INT)
--
-- \-- The function should return @n products with the highest unit prices
--
-- \-- that are supplied by the given supplier id
--
-- \-- Tables involved: Production.Products
--
--
--
-- \-- Desired output when issuing the following query:
--
-- \-- SELECT \* FROM Production.TopProducts(5, 2)
--
--
--
-- productid   productname                              unitprice
--
-- \----------- ---------------------------------------- ---------------------
--
-- 12          Product OSFNS                            38.00
--
-- 11          Product QMVUN                            21.00

-- %%
--Query using TSQLV6 database
USE TSQLV6;

CREATE FUNCTION Production.TopProducts 
(
    @supid INT,
    @n INT
)
RETURNS TABLE
AS
RETURN
(
    SELECT TOP (@n) productid, productname, unitprice
    FROM Production.Products
    WHERE supplierid = @supid
    ORDER BY unitprice DESC
);
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.016

-- %%
--Query using TSQLV6 database
USE TSQLV6;

SELECT * FROM Production.TopProducts(5, 2)
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.041
-- <table><tr><th>productid</th><th>productname</th><th>unitprice</th></tr><tr><td>12</td><td>Product OSFNS</td><td>38.00</td></tr><tr><td>11</td><td>Product QMVUN</td><td>21.00</td></tr></table>

-- %% [markdown]
-- **Explanation for the TSQLV6 Query**
--
-- **Proposition:** Create a function that accepts two input parameters @supid (supplier ID) and @n (requested number of products) and returns a table with the top @n products having the highest unit prices supplied by the given supplier ID
--
-- **Table:**
--
-- - Production.Products
--
-- **Columns:**
--
-- - productid
-- - productname
-- - unitprice
-- - supplierid
--
-- **Predicate:**
--
-- - The function filters the rows from Production.Products table based on the supplierid column matching the input parameter @supid
-- - It selects the top @n products with the highest unit prices and orders them in descending order by unitprice

-- %%
-- Query using Northwinds2022TSQLV7 database 
USE Northwinds2022TSQLV7;

CREATE FUNCTION Production.TopProducts
(
    @supid INT,
    @n INT
)
RETURNS TABLE
AS
RETURN
(
    SELECT TOP (@n) ProductId, ProductName, UnitPrice
    FROM Production.[Products]
    WHERE SupplierId = @supid
    ORDER BY UnitPrice DESC
);
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.028

-- %%
-- Query using Northwinds2022TSQLV7 database 
USE Northwinds2022TSQLV7;

SELECT * FROM Production.[TopProducts](5, 2)
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.030
-- <table><tr><th>productid</th><th>productname</th><th>unitprice</th></tr><tr><td>12</td><td>Product OSFNS</td><td>38.00</td></tr><tr><td>11</td><td>Product QMVUN</td><td>21.00</td></tr></table>

-- %% [markdown]
-- ### **Explanation for the Northwinds2022TSQLV7 Query**
--
-- **Proposition:** The function accepts two inputs @supid (supplier ID) and @n (requested number of products) and returns a table containing the top @n products with the highest unit prices supplied by the given supplier ID
--
-- **Tables:**
--
-- - Production.\[Products\]
--
-- **Columns:**
--
-- - ProductID
-- - ProductName
-- - UnitPrice
--
-- **Predicate:**
--
-- - Filters rows from the Production.\[Products\] table based on the SupplierId column matching the input parameter @supid
-- - It selects the top @n products with the highest unit prices from the filtered results and orders them in descending order by UnitPrice
-- - Function then returns this filtered and ordered result set as a table.

-- %% [markdown]
-- **\-- 6-2**
--
-- \-- Using the CROSS APPLY operator
--
-- \-- and the function you created in exercise 6-1,
--
-- \-- return, for each supplier, the two most expensive products
--
--
--
-- \-- Desired output
--
-- supplierid  companyname     productid   productname     unitprice
--
-- \----------- --------------- ----------- --------------- ----------
--
-- 8           Supplier BWGYE  20          Product QHFFP   81.00
--
-- 8           Supplier BWGYE  68          Product TBTBL   12.50
--
-- 20          Supplier CIYNM  43          Product ZZZHR   46.00
--
-- 20          Supplier CIYNM  44          Product VJIEO   19.45
--
-- 23          Supplier ELCRN  49          Product FPYPN   20.00
--
-- 23          Supplier ELCRN  76          Product JYGFE   18.00
--
-- 5           Supplier EQPNC  12          Product OSFNS   38.00
--
-- 5           Supplier EQPNC  11          Product QMVUN   21.00

-- %%
--Query using TSQLV6 database
USE TSQLV6;

SELECT 
    s.supplierid,
    s.companyname,
    tp.productid,
    tp.productname,
    tp.unitprice
FROM 
    Production.Suppliers s
CROSS APPLY
    Production.TopProducts(s.supplierid, 2) tp;
-- Out:
-- (55 rows affected)
-- Total execution time: 00:00:00.024
-- ...

-- %% [markdown]
-- **Explanation for the TSQLV6 Query**
--
-- **Proposition:** Retrieves the two most expensive products for each supplier from Production.Suppliers table using a user-defined table-valued function named Production.TopProducts and is combined using the CROSS APPLY operator
--
-- **Table:**
--
-- - Production.Suppliers
--
-- **Columns:**
--
-- - supplierid
-- - companyname
-- - productid
-- - productname
-- - unitprice
--
-- **Predicate:**
--
-- - The function returns the two most expensive products for each supplier
-- - The result has columns from both Suppliers table and the result of the function call, providing details about each supplier and their top two products sorted by unit price

-- %%
-- Query using Northwinds2022TSQLV7 database 
USE Northwinds2022TSQLV7;

SELECT 
    s.SupplierId,
    s.CompanyName,
    tp.ProductId,
    tp.ProductName,
    tp.UnitPrice
FROM 
    Production.[Supplier] s
CROSS APPLY
    Production.[TopProducts](s.SupplierId, 2) tp;
-- Out:
-- (55 rows affected)
-- Total execution time: 00:00:00.036
-- ...

-- %% [markdown]
-- ### **Explanation for the Northwinds2022TSQLV7 Query**
--
-- **Proposition:** Retrieve data that contains the two most expensive products for each supplier and combine the two using the CROSS APPLY operator.
--
-- **Tables:**
--
-- - Production.Supplier
--
-- **Columns:**
--
-- - <span style="color: var(--vscode-foreground);">SupplierId</span>
--
-- - CompanyName
-- - ProductId
-- - ProductName
-- - UnitPrice
--
-- **Predicate:**
--
-- - The function returns the two most expensive productsfor each supplier
-- - Results in a dataset containing columns from both the Supplier table and the result of the function call

-- %% [markdown]
-- ## **Part 2:**
--
-- **Chapter 4 | Lines 219-276**
--
-- \---------------------------------------------------------------------
--
-- \-- Misbehaving Subqueries
--
-- \---------------------------------------------------------------------
--
-- \---------------------------------------------------------------------
--
-- \-- NULL Trouble
--
-- \---------------------------------------------------------------------
--
-- **Preposition:**
--
-- Write a query that identifies customers from the  Sales.Customers table who haven't placed any orders and if the custid is NULL delete it from the Sales.Orders table.
--
-- **Tables:**
--
-- - Sales.Orders
--
-- **Columns:**
--
-- - custid
-- - companyname
--
-- **Predicate:**
--
-- - Selects customer IDs (custid) and company names (companyname) from the Sales.Customers table where there doesn't exist any corresponding record in the Sales.Orders table with the same custid
-- - The DELETE statement removes any records from the Sales.Orders table where the custid is NULL. This ensures data integrity by removing invalid or incomplete records.

-- %%
--Query using TSQLV6 database
USE TSQLV6;

-- Using NOT EXISTS
SELECT custid, companyname
FROM Sales.Customers AS C
WHERE NOT EXISTS
  (SELECT * 
   FROM Sales.Orders AS O
   WHERE O.custid = C.custid);

-- Cleanup
DELETE FROM Sales.Orders WHERE custid IS NULL;


--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;

-- Using NOT EXISTS
SELECT CustomerId, CustomerCompanyName
FROM Sales.[Customer] AS C
WHERE NOT EXISTS
  (SELECT * 
   FROM Sales.[Order] AS O
   WHERE O.CustomerId = C.CustomerId);

-- Cleanup
DELETE FROM Sales.[Order] WHERE CustomerId IS NULL;
-- Out:
-- (2 rows affected)
-- (0 rows affected)
-- (2 rows affected)
-- (0 rows affected)
-- Total execution time: 00:00:00.022
-- <table><tr><th>custid</th><th>companyname</th></tr><tr><td>22</td><td>Customer DTDMN</td></tr><tr><td>57</td><td>Customer WVAXS</td></tr></table>
-- <table><tr><th>CustomerId</th><th>CustomerCompanyName</th></tr><tr><td>22</td><td>Customer DTDMN</td></tr><tr><td>57</td><td>Customer WVAXS</td></tr></table>

-- %% [markdown]
-- \---------------------------------------------------------------------
--
-- \-- Substitution Error in a Subquery Column Name
--
-- \---------------------------------------------------------------------
--
-- **Preposition:**
--
-- Create a table Sales.MyShippers to store information about shippers and populate it with data for three shippers, including their shipper IDs, company names, and phone numbers.
--
-- **Tables:**
--
-- - Sales.MyShippers
--
-- **Columns:**
--
-- - shipper\_id
-- - companyname
-- - phone
--
-- **Predicate:**
--
-- - The table inserts  three records into the table to populate it with information about different shippers and each record includes shipper ID, company name, and phone number for a shipper

-- %%
--Query using TSQLV6 database
USE TSQLV6;
-- Create and populate table Sales.MyShippers

DROP TABLE IF EXISTS Sales.MyShippers;

CREATE TABLE Sales.MyShippers

(

  shipper_id  INT          NOT NULL,

  companyname NVARCHAR(40) NOT NULL,

  phone       NVARCHAR(24) NOT NULL,

  CONSTRAINT PK_MyShippers PRIMARY KEY(shipper_id)

);

INSERT INTO Sales.MyShippers(shipper_id, companyname, phone)

  VALUES(1, N'Shipper GVSUA', N'(503) 555-0137'),

      (2, N'Shipper ETYNR', N'(425) 555-0136'),

(3, N'Shipper ZHISN', N'(415) 555-0138');
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.052

-- %%
--Query using TSQLV6 database
USE TSQLV6;

SELECT * FROM Sales.MyShippers;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.013
-- <table><tr><th>shipper_id</th><th>companyname</th><th>phone</th></tr><tr><td>1</td><td>Shipper GVSUA</td><td>(503) 555-0137</td></tr><tr><td>2</td><td>Shipper ETYNR</td><td>(425) 555-0136</td></tr><tr><td>3</td><td>Shipper ZHISN</td><td>(415) 555-0138</td></tr></table>

-- %% [markdown]
-- **Preposition:**
--
-- Retreive information about shippers who shipped orders to customer 43 from the Sales.Shippers table.
--
-- **Tables:**
--
-- - <span style="color: var(--vscode-foreground);">Sales.Shippers</span>
--
-- - Sales.Orders
--
--
-- **Columns:**
--
-- - shipperid
-- - companyname
-- - custid
--
-- **Predicate:**
--
-- - It tales the shipper IDs and company names where it exists and the subquery retrieves the shipper IDs from the Sales.Orders table where the custid  is 43.

-- %%
--Query using TSQLV6 database
USE TSQLV6;
-- Shippers who shipped orders to customer 43
-- Bug
SELECT shipperid, companyname
FROM Sales.Shippers
WHERE shipperid IN
  (SELECT shipperid
   FROM Sales.Orders
   WHERE custid = 43);

--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;
-- Shippers who shipped orders to customer 43
-- Bug
SELECT ShipperId, ShipperCompanyName
FROM Sales.[Shipper]
WHERE Shipperid IN
  (SELECT Shipperid
   FROM Sales.[Order]
   WHERE CustomerId = 43);

-----------------------------------------------------------------

--Query using TSQLV6 database
USE TSQLV6;
-- The safe way using aliases, bug identified
SELECT shipperid, companyname
FROM Sales.Shippers
WHERE shipperid IN
  (SELECT O.shipperid
   FROM Sales.Orders AS O
   WHERE O.custid = 43);

--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;
-- The safe way using aliases, bug identified
SELECT Shipperid, ShipperCompanyName
FROM Sales.[Shipper]
WHERE Shipperid IN
  (SELECT O.Shipperid
   FROM Sales.[Order] AS O
   WHERE O.CustomerId = 43);

---------------------------------------------------------------

--Query using TSQLV6 database
USE TSQLV6;
-- Bug corrected
SELECT shipperid, companyname
FROM Sales.Shippers
WHERE shipperid IN
  (SELECT O.shipperid
   FROM Sales.Orders AS O
   WHERE O.custid = 43);

--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;
-- Bug corrected
SELECT Shipperid, ShipperCompanyName
FROM Sales.[Shipper]
WHERE Shipperid IN
  (SELECT O.Shipperid
   FROM Sales.[Order] AS O
   WHERE O.CustomerId = 43);

-- Cleanup
DROP TABLE IF EXISTS Sales.MyShippers;
-- Out:
-- (2 rows affected)
-- (2 rows affected)
-- (2 rows affected)
-- (2 rows affected)
-- (2 rows affected)
-- (2 rows affected)
-- Total execution time: 00:00:00.056
-- <table><tr><th>shipperid</th><th>companyname</th></tr><tr><td>2</td><td>Shipper ETYNR</td></tr><tr><td>3</td><td>Shipper ZHISN</td></tr></table>
-- <table><tr><th>ShipperId</th><th>ShipperCompanyName</th></tr><tr><td>2</td><td>Shipper ETYNR</td></tr><tr><td>3</td><td>Shipper ZHISN</td></tr></table>
-- <table><tr><th>shipperid</th><th>companyname</th></tr><tr><td>2</td><td>Shipper ETYNR</td></tr><tr><td>3</td><td>Shipper ZHISN</td></tr></table>
-- <table><tr><th>Shipperid</th><th>ShipperCompanyName</th></tr><tr><td>2</td><td>Shipper ETYNR</td></tr><tr><td>3</td><td>Shipper ZHISN</td></tr></table>
-- <table><tr><th>shipperid</th><th>companyname</th></tr><tr><td>2</td><td>Shipper ETYNR</td></tr><tr><td>3</td><td>Shipper ZHISN</td></tr></table>
-- ...

-- %% [markdown]
-- **Chapter 5 | Lines 383-490**
--
-- \---------------------------------------------------------------------
--
-- \-- CHECK OPTION
--
-- \---------------------------------------------------------------------
--
-- **Preposition:**
--
-- Insert a new row into Sales.Customers table through a view. Then, cleanup by deleting rows from the Sales.Customers table where the custid is greater than 91 and dropping the view Sales.USACusts.
--
-- **Tables:**
--
-- - Sales.Customers
--
-- **Columns:**
--
-- - companyname
-- - contactname
-- - contacttitle
-- - address
-- - city
-- - region
-- - postalcode
-- - country
-- - phone
-- - fax
--
-- **Predicate:**
--
-- - Inserts a new row into the Sales.Customers table specifying the vairous columns. Then it will try to delete the rows from the Sales.Customers table where the custid is greater than 91
-- - It drops the view Sales.USACusts if it exists

-- %%
--Query using TSQLV6 database
USE TSQLV6;
-- Notice that you can't insert a row through the view
INSERT INTO Sales.Customers(
  companyname, contactname, contacttitle, address,
  city, region, postalcode, country, phone, fax)
 VALUES(
  N'Customer FGHIJ', N'Contact FGHIJ', N'Title FGHIJ', N'Address FGHIJ',
  N'London', NULL, N'12345', N'UK', N'012-3456789', N'012-3456789');

GO

-- Cleanup
DELETE FROM Sales.Customers
WHERE custid > 91;

DROP VIEW IF EXISTS Sales.USACusts;
GO


--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;
-- Notice that you can't insert a row through the view
INSERT INTO Sales.[Customer](
  CustomerCompanyName, CustomerContactName, CustomerContactTitle, CustomerAddress,
  CustomerCity, CustomerRegion, CustomerPostalCode, CustomerCountry, CustomerPhoneNumber, CustomerFaxNumber)
 VALUES(
  N'Customer FGHIJ', N'Contact FGHIJ', N'Title FGHIJ', N'Address FGHIJ',
  N'London', NULL, N'12345', N'UK', N'012-3456789', N'012-3456789');

GO

-- Cleanup
DELETE FROM Sales.[Customer]
WHERE customerid > 91;

DROP VIEW IF EXISTS Sales.USACusts;
GO
-- Out:
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:00.168

-- %% [markdown]
-- \---------------------------------------------------------------------
--
-- \-- Inline User Defined Functions
--
-- \---------------------------------------------------------------------
--
-- **Preposition:**
--
-- Create or alter a function named dbo.GetCustOrders in the TSQLV6 database to retrieve orders for a specific customer ID. Then test the function by selecting order information for customer ID 1 and joining it with order details.
--
-- **Tables:**
--
-- - Sales.Orders
-- - Sales.OrderDetails
--
-- **Columns:**
--
-- - <span style="color: var(--vscode-foreground);">orderid</span>
-- - <span style="color: var(--vscode-foreground);">custid</span>
-- - <span style="color: var(--vscode-foreground);">empid</span>
-- - <span style="color: var(--vscode-foreground);">orderdate</span>
-- - <span style="color: var(--vscode-foreground);">requireddate</span>
-- - shippeddate
-- - shipperid
-- - freight
-- - shipname
-- - shipaddress
-- - shipcity
-- - shipregion
-- - shippostalcode
-- - shipcountry
--
-- **Predicate:**
--
-- - The function named dbo.GetCustOrders returns the order information for a specific customer ID (@cid)
-- - Then tests the function by ordering the information for customer  ID 1 and joining it with order details to retrieve product information
-- - Then it cleans up the function by dropping the function dbo.GetCustOrders if it exists

-- %%
--Query using TSQLV6 database
USE TSQLV6;
GO
-- Creating GetCustOrders function

CREATE OR ALTER FUNCTION dbo.GetCustOrders
  (@cid AS INT) RETURNS TABLE
AS
RETURN
  SELECT orderid, custid, empid, orderdate, requireddate,
    shippeddate, shipperid, freight, shipname, shipaddress, shipcity,
    shipregion, shippostalcode, shipcountry
  FROM Sales.Orders
  WHERE custid = @cid;
GO
-- Test Function
SELECT orderid, custid
FROM dbo.GetCustOrders(1) AS O;

SELECT O.orderid, O.custid, OD.productid, OD.qty
FROM dbo.GetCustOrders(1) AS O
  INNER JOIN Sales.OrderDetails AS OD
    ON O.orderid = OD.orderid;
GO

-- Cleanup
DROP FUNCTION IF EXISTS dbo.GetCustOrders;
GO


--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;
GO
-- Creating GetCustOrders function

CREATE OR ALTER FUNCTION dbo.GetCustOrders
  (@cid AS INT) RETURNS TABLE
AS
RETURN
  SELECT OrderId, CustomerId, EmployeeId, OrderDate, RequiredDate,
    ShipToDate, shipperid, freight, ShipToName, ShipToAddress, ShipToCity,
    ShipToRegion, ShipToPostalCode, ShipToCountry
  FROM Sales.[Order]
  WHERE CustomerId = @cid;
GO
-- Test Function
SELECT OrderId, CustomerId
FROM dbo.GetCustOrders(1) AS O;

SELECT O.OrderId, O.CustomerId, OD.ProductId, OD.Quantity
FROM dbo.GetCustOrders(1) AS O
  INNER JOIN Sales.[OrderDetail] AS OD
    ON O.OrderId = OD.OrderId;
GO

-- Cleanup
DROP FUNCTION IF EXISTS dbo.GetCustOrders;
GO
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- (6 rows affected)
-- (12 rows affected)
-- Commands completed successfully.
-- Commands completed successfully.
-- Commands completed successfully.
-- (6 rows affected)
-- (12 rows affected)
-- Commands completed successfully.
-- Total execution time: 00:00:00.164
-- <table><tr><th>orderid</th><th>custid</th></tr><tr><td>10643</td><td>1</td></tr><tr><td>10692</td><td>1</td></tr><tr><td>10702</td><td>1</td></tr><tr><td>10835</td><td>1</td></tr><tr><td>10952</td><td>1</td></tr><tr><td>11011</td><td>1</td></tr></table>
-- ...

-- %% [markdown]
-- \---------------------------------------------------------------------
--
-- \-- APPLY
--
-- \---------------------------------------------------------------------
--
-- **Preposition:**
--
-- Retrieves the shipper IDs and employee IDs by performing a cross join and a cross apply operation between the Sales.Shippers table and the HR.Employees table
--
-- **Tables:**
--
-- - Sales.Shippers
-- - HR.Employees
--
-- **Columns:**
--
-- - S.shipperid
-- - E.empid
--
-- **Predicate:**
--
-- - A cross join between Sales.Shippers table and the HR.Employees table is performed. It generates all  combinations of shipper IDs and employee IDs
-- - Each row from Sales.Shippers table is combined with HR.Employees table, resulting in a Cartesian product
-- - Then a cross apply operation is performed and it filters based on each row of the outer table.
-- - Each row from the Sales.Shippers table is combined with only the rows from the HR.Employees table that satisfy certain conditions
-- - Cross apply results in a constrained result compared to cross join

-- %%
--Query using TSQLV6 database
USE TSQLV6;

SELECT S.shipperid, E.empid
FROM Sales.Shippers AS S
  CROSS JOIN HR.Employees AS E;

SELECT S.shipperid, E.empid
FROM Sales.Shippers AS S
  CROSS APPLY HR.Employees AS E;


--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;

SELECT S.ShipperId, E.EmployeeId
FROM Sales.[Shipper] AS S
  CROSS JOIN HumanResources.[Employee] AS E;

SELECT S.Shipperid, E.EmployeeId
FROM Sales.[Shipper] AS S
  CROSS APPLY HumanResources.[Employee] AS E;
-- Out:
-- (27 rows affected)
-- (27 rows affected)
-- (27 rows affected)
-- (27 rows affected)
-- Total execution time: 00:00:00.045
-- <table><tr><th>shipperid</th><th>empid</th></tr><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>3</td></tr><tr><td>1</td><td>4</td></tr><tr><td>1</td><td>5</td></tr><tr><td>1</td><td>6</td></tr><tr><td>1</td><td>7</td></tr><tr><td>1</td><td>8</td></tr><tr><td>1</td><td>9</td></tr><tr><td>2</td><td>1</td></tr><tr><td>2</td><td>2</td></tr><tr><td>2</td><td>3</td></tr><tr><td>2</td><td>4</td></tr><tr><td>2</td><td>5</td></tr><tr><td>2</td><td>6</td></tr><tr><td>2</td><td>7</td></tr><tr><td>2</td><td>8</td></tr><tr><td>2</td><td>9</td></tr><tr><td>3</td><td>1</td></tr><tr><td>3</td><td>2</td></tr><tr><td>3</td><td>3</td></tr><tr><td>3</td><td>4</td></tr><tr><td>3</td><td>5</td></tr><tr><td>3</td><td>6</td></tr><tr><td>3</td><td>7</td></tr><tr><td>3</td><td>8</td></tr><tr><td>3</td><td>9</td></tr></table>
-- ...

-- %% [markdown]
-- **Preposition:**
--
-- Retrieve the three most recent orders for each customer from the Sales.Customers table by performing a cross apply operation with a subquery selecting the top three orders for each customer from the Sales.Orders table
--
-- **Tables:**
--
-- - Sales.Customers
-- - Sales.Orders
--
-- **Columns:**
--
-- - <span style="color: var(--vscode-foreground);">custid</span>
--
-- - orderid
--
-- - orderdate
--
-- - empid
--
-- - requireddate
--
--
-- **Predicate:**
--
-- - A cross apply operation is used to combine each row from the Sales.Customers table with the top three most recent orders from the corresponding customer from the Sales.Orders table
-- - The subquery inside takes the top three orders for each customer and is filtered based on the customer ID (O.custid = C.custid) and orders the reults by the order date in descending order (latest orders first), and then by order ID in descending order (to break ties if multiple orders have the same order date)

-- %%
--Query using TSQLV6 database
USE TSQLV6;

-- 3 most recent orders for each customer
SELECT C.custid, A.orderid, A.orderdate
FROM Sales.Customers AS C
  CROSS APPLY
    (SELECT TOP (3) orderid, empid, orderdate, requireddate 
     FROM Sales.Orders AS O
     WHERE O.custid = C.custid
     ORDER BY orderdate DESC, orderid DESC) AS A;

--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;

-- 3 most recent orders for each customer
SELECT C.Customerid, A.OrderId, A.OrderDate
FROM Sales.[Customer] AS C
  CROSS APPLY
    (SELECT TOP (3) Orderid, e=EmployeeId, OrderDate, RequiredDate 
     FROM Sales.[Order] AS O
     WHERE O.CustomerId = C.CustomerId
     ORDER BY OrderDate DESC, OrderId DESC) AS A;
-- Out:
-- (263 rows affected)
-- (263 rows affected)
-- Total execution time: 00:00:00.094
-- ...

-- %% [markdown]
-- **Preposition:**
--
-- Retrieve the three most recent orders for each customer from the Sales.Customers table by using a cross apply operation with a subquery selecting the top three orders for each customer from the Sales.Orders table
--
-- **Tables:**
--
-- - Sales.Customers
-- - Sales.Orders
--
-- **Columns:**
--
-- - <span style="color: var(--vscode-foreground);">custid</span>
--
-- - orderid
--
-- - orderdate
--
-- - empid
--
-- - requireddate
--
--
-- **Predicate:**
--
-- - A cross apply operation to combine each row from the Sales.Customers table with the top three most recent orders for the corresponding customer from the Sales.Orders table
-- - The subquery takes the top three orders for each customer by filtering based on the customer ID (O.custid = C.custid), ordering the results by order date in descending order (latest orders first), and then by order ID in descending order (to break ties if multiple orders have the same order date)
-- - The OFFSET 0 ROWS FETCH NEXT 3 ROWS ONLY clause is used to limit the result set to the first three rows

-- %%
--Query using TSQLV6 database
USE TSQLV6;

-- With OFFSET-FETCH
SELECT C.custid, A.orderid, A.orderdate
FROM Sales.Customers AS C
  CROSS APPLY
    (SELECT orderid, empid, orderdate, requireddate 
     FROM Sales.Orders AS O
     WHERE O.custid = C.custid
     ORDER BY orderdate DESC, orderid DESC
     OFFSET 0 ROWS FETCH NEXT 3 ROWS ONLY) AS A;


--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;

-- With OFFSET-FETCH
SELECT C.CustomerId, A.OrderId, A.OrderDate
FROM Sales.[Customer] AS C
  CROSS APPLY
    (SELECT OrderId, EmployeeId, OrderDate, RequiredDate 
     FROM Sales.[Order] AS O
     WHERE O.CustomerId = C.CustomerId
     ORDER BY orderdate DESC, orderid DESC
     OFFSET 0 ROWS FETCH NEXT 3 ROWS ONLY) AS A;
-- Out:
-- (263 rows affected)
-- (263 rows affected)
-- Total execution time: 00:00:00.153
-- ...

-- %% [markdown]
-- **Preposition:**
--
-- Retrieve the three most recent orders for each customer from the Sales.Customers table while preserving all customers, including those without any orders, by performing an outer apply operation with a subquery selecting the top three orders for each customer from the Sales.Orders table
--
-- **Tables:**
--
-- - Sales.Customers
-- - Sales.Orders
--
-- **Columns:**
--
-- - <span style="color: var(--vscode-foreground);">custid</span>
--
-- - orderid
--
-- - orderdate
--
-- - empid
--
-- - requireddate
--
--
-- **Predicate:**
--
-- - A outter apply operation is used to combine each row from the Sales.Customers table with the top three most recent orders for the corresponding customer from the Sales.Orders table
-- - The subquery takes the top three orders for each customer by filtering based on the customer ID (O.custid = C.custid), ordering the results by order date in descending order (latest orders first), and then by order ID in descending order (to break ties if multiple orders have the same order date)

-- %%
--Query using TSQLV6 database
USE TSQLV6;

-- 3 most recent orders for each customer, preserve all customers
SELECT C.custid, A.orderid, A.orderdate
FROM Sales.Customers AS C
  OUTER APPLY
    (SELECT TOP (3) orderid, empid, orderdate, requireddate 
     FROM Sales.Orders AS O
     WHERE O.custid = C.custid
     ORDER BY orderdate DESC, orderid DESC) AS A;
GO

--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;

-- 3 most recent orders for each customer, preserve all customers
SELECT C.CustomerId, A.OrderId, A.OrderDate
FROM Sales.[Customer] AS C
  OUTER APPLY
    (SELECT TOP (3) OrderId, EmployeeId, OrderDate, RequiredDate 
     FROM Sales.[Order] AS O
     WHERE O.CustomerId = C.CustomerId
     ORDER BY orderdate DESC, orderid DESC) AS A;
GO
-- Out:
-- (265 rows affected)
-- (265 rows affected)
-- Total execution time: 00:00:00.100
-- ...

-- %% [markdown]
-- **Preposition:**
--
-- Create or alter a table named dbo.TopOrders and take two parameters @custid and @n, and returns a table containing the top @n orders for a specific customer ID (@custid). Then use CROSS APPLY to apply the function to each row in the Sales.Customers table, retrieving the top 3 orders for each customer
--
-- **Tables:**
--
-- - Sales.Orders
-- - Sales.Customers
--
-- **Columns:**
--
-- - orderid
-- - empid
-- - orderdate
-- - requireddate
-- - custid
-- - companyname
--
-- **Predicate:**
--
-- - This function selects the data from Sales.Customers table and retrieves the top 3 orders for each customer based on the specified parameters (@custid and 3)
-- - It is then filtered based on customer ID, ordering them by order date in descending order and then by order ID in descending order

-- %%
--Query using TSQLV6 database
USE TSQLV6;
GO
-- Creation Script for the Function TopOrders
CREATE OR ALTER FUNCTION dbo.TopOrders
  (@n AS INT, @custid AS INT)
  RETURNS TABLE
AS
RETURN
  SELECT TOP (@n) orderid, empid, orderdate, requireddate
  FROM Sales.Orders
  WHERE custid = @custid
  ORDER BY orderdate DESC, orderid DESC;
GO

SELECT
  C.custid, C.companyname,
  A.orderid, A.empid, A.orderdate, A.requireddate 
FROM Sales.Customers AS C
  CROSS APPLY dbo.TopOrders(C.custid, 3) AS A;


--Query using Northwinds2022TSQLV7
USE Northwinds2022TSQLV7;
GO
-- Creation Script for the Function TopOrders
CREATE OR ALTER FUNCTION dbo.TopOrders
  (@custid AS INT, @n AS INT)
  RETURNS TABLE
AS
RETURN
  SELECT TOP (@n) OrderId, EmployeeId, OrderDate, RequiredDate
  FROM Sales.[Order]
  WHERE CustomerId = @custid
  ORDER BY OrderDate DESC, OrderId DESC;
GO

SELECT
  C.CustomerId, C.CustomerCompanyName,
  A.OrderId, A.EmployeeId, A.OrderDate, A.RequiredDate 
FROM Sales.[Customer] AS C
  CROSS APPLY dbo.TopOrders(C.CustomerId, 3) AS A;
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- (616 rows affected)
-- Commands completed successfully.
-- (263 rows affected)
-- Total execution time: 00:00:00.077
-- ...
